# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/CatEncodersFamily/blob/main/kidneystone_breastcancer_pca_xgb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demo with Kidney stone data set
# Data source is [here](https://www.kaggle.com/datasets/vuppalaadithyasairam/kidney-stone-prediction-based-on-urine-analysis
# ).

# %%
# Last amended: 6th June, 2023

# %% [markdown]
# ## Basics

# %%
# %reset -f

# %%
# !pip install catencfamily
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: catencfamily in /usr/local/lib/python3.10/dist-packages (0.0.65)
# Requirement already satisfied: cdlib in /usr/local/lib/python3.10/dist-packages (from catencfamily) (0.2.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catencfamily) (3.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from catencfamily) (2.8.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.5.3)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.2.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.18.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (4.65.0)
# Requirement already satisfied: demon in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (2.0.6)
# Requirement already satisfied: python-louvain>=0.16 in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.16)
# Requirement already satisfied: nf1 in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (1.10.1)
# Requirement already satisfied: pulp in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (2.7.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.12.2)
# Requirement already satisfied: eva-lcd in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.1.1)
# Requirement already satisfied: bimlpa in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.1.2)
# Requirement already satisfied: markov-clustering in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.0.6.dev0)
# Requirement already satisfied: chinese-whispers in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.8.1)
# Requirement already satisfied: python-igraph in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.10.4)
# Requirement already satisfied: angel-cd in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (1.0.3)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (1.6.0)
# Requirement already satisfied: dynetx in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.3.2)
# Requirement already satisfied: thresholdclustering in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (1.1)
# Requirement already satisfied: pyclustering in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.10.1.2)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.29.34)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->catencfamily) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->catencfamily) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->catencfamily) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->catencfamily) (1.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from dynetx->cdlib->catencfamily) (4.4.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch->cdlib->catencfamily) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch->cdlib->catencfamily) (2.27.1)
# Requirement already satisfied: igraph==0.10.4 in /usr/local/lib/python3.10/dist-packages (from python-igraph->cdlib->catencfamily) (0.10.4)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph==0.10.4->python-igraph->cdlib->catencfamily) (1.6.7)
# Requirement already satisfied: Levenshtein==0.21.0 in /usr/local/lib/python3.10/dist-packages (from python-Levenshtein->cdlib->catencfamily) (0.21.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein==0.21.0->python-Levenshtein->cdlib->catencfamily) (3.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (3.4)

# %%
# 1.0 Call libraries
import pandas as pd
import numpy as np


# 1.01
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


# 1.02
import matplotlib.pyplot as plt
import seaborn as sns


# 1.03
import xgboost as xgb


# 1.04
from catencfamily.encoders import CatEncodersFamily
from catencfamily import utils
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'karateclub', 'leidenalg', 'wurlitzer', 'graph_tool', 'infomap'}
# Note: to be able to use all overlapping methods, you need to install some additional packages:  {'ASLPAw', 'karateclub'}
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'leidenalg', 'wurlitzer', 'infomap'}

# %%
# 1.05 Display multiple commands output from a cell:
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# 2.0 Read kidney stone data:

data = pd.read_csv("https://raw.githubusercontent.com/harnalashok/CatEncodersFamily/main/datasets/kidney_stone.csv")
data.head(3)
# Out:
#    id  gravity    ph  osmo  cond  urea  calc  target
# 0   0    1.013  6.19   443  14.8   124  1.45       0
# 1   1    1.025  5.40   703  23.6   394  4.18       0
# 2   2    1.009  6.13   371  24.5   159  9.04       0

# %%
# 2.1
data.shape   # (414, 8)

print("\n==dtypes====\n")
data.dtypes
# Out:
# (414, 8)
# ==dtypes====
# id           int64
# gravity    float64
# ph         float64
# osmo         int64
# cond       float64
# urea         int64
# calc       float64
# target       int64
# dtype: object

# %%
# 2.2 pop out target and id:

y = data.pop("target")
_ = data.pop("id")

# %%
# 2.21 Proportions of 1s and 0s
y.value_counts(normalize = True)
# Out:
# 0    0.555556
# 1    0.444444
# Name: target, dtype: float64

# %%
# 2.3 Check nulls and any need for imputing?

data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Transform numeric data to categorical
# We transform our data as if it were categorical. (of course, such transformation is imperfect.)

# %% [markdown]
# To perform our experiments we bin all numeric columns to transform the data to categorical. Binning is performed using pandas `cut()` method. Subsequently we will transform the categorical data to numeric using the approach given in CatEncodersFamily.
#
# While binning, we also split the data: both the numeric (the original) as also the binned datasets. Spliting is performed in stratified manner using `train_test_split()` function of sklearn; `target (y)` is used to stratify. While splitting, for easy comparison, we  see to it that same set of rows occur in `orig_train` and `train_binned` on the one hand and `orig_test` and `test_binned` on the other hand.

# %%
# 3.0 Discretise all features of data. And also split dataset.
#     into train/test:

orig_train, orig_test, train_binned, test_binned  = utils.transformToCatFeatures(data,
                                                                              y,
                                                                              bins = 30,
                                                                              test_size = 0.1,
                                                                              genColName = False  # Keep orig col names
                                                                              )

# %%
# 3.0.1 Check  original data:
#       It has target col also:

orig_train.shape
print("\n======\n")
orig_train.head(3)
orig_test.head(3)
# Out:
# (373, 7)
# ======
#      gravity    ph   osmo  cond   urea  calc  target
# 43     1.021  6.13  907.0  23.6  448.0  2.45       1
# 96     1.012  5.62  461.0  17.4  195.0  2.17       0
# 151    1.021  5.53  658.0  23.6  224.0  2.31       1
#      gravity    ph   osmo  cond   urea  calc  target
# 372    1.013  6.19  443.0  14.8  124.0  1.45       0
# 352    1.025  5.40  703.0  23.6  394.0  4.18       0
# 190    1.009  6.13  371.0  24.5  159.0  9.04       0

# %%
# 3.0.2 Check discretised features
#       Note the row-indices of train/test data 
#       and compare with those in the above cell.

train_binned.shape
print("\n========\n")
train_binned.head(3)
test_binned.head(3)
# Out:
# (373, 7)
# ========
#     gravity   ph  osmo  cond  urea calc  target
# 43      414  813  1221  1617  2022  245       1
# 96       46   89   128  1612  2010  245       0
# 151     414   88  1214  1617  2011  245       1
#     gravity   ph  osmo  cond  urea  calc  target
# 372      47  814   128   169   206   243       0
# 352     418   87  1215  1617  2019   249       0
# 190      44  813   126  1618   208  2419       0

# %%
# 3.1 Pop out targets:

ytr = train_binned.pop('target')
yte = test_binned.pop("target")

# %% [markdown]
# ## Transform categorical data to numeric
# We use `CatEncodersFamily` class for transformation:

# %%
## 4.0 Developing models
#      Which are our cat columns


cat_cols = list(train_binned.columns)
len(cat_cols)  # 6


# 4.1 Keep interacting cat columns, same
# as cat columns:
interactingCatCols = cat_cols
# Out:
# 6

# %%
# 5.0 Instantiate CatEncodersFamily class:

ct = CatEncodersFamily(
                       cMeasures=[1,1,1,1,None,1,1],
                       )

# 5.1 Fit it using only train_binned dataset.
#     While fitting, 'target' is not needed:


ct.fit(train_binned, cat_cols, interactingCatCols)
# Out:
# Record set no is 1
# Set of records is:  [('gravity', 'ph', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'osmo', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'cond', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'urea', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'calc', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'ph_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'osmo_p_urea', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'gravity_p_urea', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'gravity_p_calc', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'osmo_p_cond', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'osmo_p_calc', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'gravity_p_ph', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'gravity_p_cond', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'cond_p_urea', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'ph_p_cond', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'gravity_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'ph_p_urea', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'cond_p_calc', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'ph_p_calc', [1, 1, 1, 1, None, 1, 1]), ('gravity', 'urea_p_calc', [1, 1, 1, 1, None, 1, 1]), ('ph', 'gravity', [1, 1, 1, 1, None, 1, 1]), ('ph', 'osmo', [1, 1, 1, 1, None, 1, 1]), ('ph', 'cond', [1, 1, 1, 1, None, 1, 1]), ('ph', 'urea', [1, 1, 1, 1, None, 1, 1]), ('ph', 'calc', [1, 1, 1, 1, None, 1, 1]), ('ph', 'ph_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('ph', 'osmo_p_urea', [1, 1, 1, 1, None, 1, 1]), ('ph', 'gravity_p_urea', [1, 1, 1, 1, None, 1, 1]), ('ph', 'gravity_p_calc', [1, 1, 1, 1, None, 1, 1]), ('ph', 'osmo_p_cond', [1, 1, 1, 1, None, 1, 1]), ('ph', 'osmo_p_calc', [1, 1, 1, 1, None, 1, 1]), ('ph', 'gravity_p_ph', [1, 1, 1, 1, None, 1, 1]), ('ph', 'gravity_p_cond', [1, 1, 1, 1, None, 1, 1]), ('ph', 'cond_p_urea', [1, 1, 1, 1, None, 1, 1]), ('ph', 'ph_p_cond', [1, 1, 1, 1, None, 1, 1]), ('ph', 'gravity_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('ph', 'ph_p_urea', [1, 1, 1, 1, None, 1, 1]), ('ph', 'cond_p_calc', [1, 1, 1, 1, None, 1, 1]), ('ph', 'ph_p_calc', [1, 1, 1, 1, None, 1, 1]), ('ph', 'urea_p_calc', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'gravity', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'ph', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'cond', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'urea', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'calc', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'ph_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'osmo_p_urea', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'gravity_p_urea', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'gravity_p_calc', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'osmo_p_cond', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'osmo_p_calc', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'gravity_p_ph', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'gravity_p_cond', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'cond_p_urea', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'ph_p_cond', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'gravity_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'ph_p_urea', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'cond_p_calc', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'ph_p_calc', [1, 1, 1, 1, None, 1, 1]), ('osmo', 'urea_p_calc', [1, 1, 1, 1, None, 1, 1]), ('cond', 'gravity', [1, 1, 1, 1, None, 1, 1]), ('cond', 'ph', [1, 1, 1, 1, None, 1, 1]), ('cond', 'osmo', [1, 1, 1, 1, None, 1, 1]), ('cond', 'urea', [1, 1, 1, 1, None, 1, 1]), ('cond', 'calc', [1, 1, 1, 1, None, 1, 1]), ('cond', 'ph_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('cond', 'osmo_p_urea', [1, 1, 1, 1, None, 1, 1]), ('cond', 'gravity_p_urea', [1, 1, 1, 1, None, 1, 1]), ('cond', 'gravity_p_calc', [1, 1, 1, 1, None, 1, 1]), ('cond', 'osmo_p_cond', [1, 1, 1, 1, None, 1, 1]), ('cond', 'osmo_p_calc', [1, 1, 1, 1, None, 1, 1]), ('cond', 'gravity_p_ph', [1, 1, 1, 1, None, 1, 1]), ('cond', 'gravity_p_cond', [1, 1, 1, 1, None, 1, 1]), ('cond', 'cond_p_urea', [1, 1, 1, 1, None, 1, 1]), ('cond', 'ph_p_cond', [1, 1, 1, 1, None, 1, 1]), ('cond', 'gravity_p_osmo', [1, 1, 1, 1, None, 1, 1]), ('cond', 'ph_p_urea', [1, 1, 1, 1, None, 1, 1]), ('cond', 'cond_p_calc', [1, 1, 1, 1, None, 1, 1]), ('cond', 'ph_p_calc', [1, 1, 1, 1, None, 1, 1]), ('cond', 'urea_p_calc', [1, 1, 1, 1, None, 1, 1 ...
#
#
#
# Next:  1  of  120 gravity ph
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  0.00013913710912068686 minutes
# Bipartite Network projected. Time taken:  4.790226618448893e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0035848657290140787 minutes
# Model saved
# Done with gravity  and  ph
# Time taken:  0.0040629029273986815
# Entry made in file progress.csv
#
#
#
# Next:  2  of  120 gravity osmo
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  9.243488311767578e-05 minutes
# Bipartite Network projected. Time taken:  2.863804499308268e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002039976914723714 minutes
# Model saved
# Done with gravity  and  osmo
# Time taken:  0.0024086634318033853
# Entry made in file progress.csv
#
#
#
# Next:  3  of  120 gravity cond
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  8.899370829264323e-05 minutes
# Bipartite Network projected. Time taken:  1.6740957895914714e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.001959089438120524 minutes
# Model saved
# Done with gravity  and  cond
# Time taken:  0.0022446552912394205
# Entry made in file progress.csv
#
#
#
# Next:  4  of  120 gravity urea
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  7.18235969543457e-05 minutes
# Bipartite Network projected. Time taken:  3.2794475555419925e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0019821405410766603 minutes
# Model saved
# Done with gravity  and  urea
# Time taken:  0.002293845017751058
# Entry made in file progress.csv
#
#
#
# Next:  5  of  120 gravity calc
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  9.101231892903646e-05 minutes
# Bipartite Network projected. Time taken:  3.5643577575683594e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0019379138946533203 minutes
# Model saved
# Done with gravity  and  calc
# Time taken:  0.0022600412368774412
# Entry made in file progress.csv
#
#
#
# Next:  6  of  120 gravity ph_p_osmo
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  8.658568064371745e-05 minutes
# Bipartite Network projected. Time taken:  1.4630953470865886e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026801625887552896 minutes
# Model saved
# Done with gravity  and  ph_p_osmo
# Time taken:  0.0030074278513590497
# Entry made in file progress.csv
#
#
#
# Next:  7  of  120 gravity osmo_p_urea
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  9.485880533854167e-05 minutes
# Bipartite Network projected. Time taken:  2.0845731099446615e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027464588483174643 minutes
# Model saved
# Done with gravity  and  osmo_p_urea
# Time taken:  0.003033872445424398
# Entry made in file progress.csv
#
#
#
# Next:  8  of  120 gravity gravity_p_urea
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  8.548498153686524e-05 minutes
# Bipartite Network projected. Time taken:  8.26120376586914e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027118325233459473 minutes
# Model saved
# Done with gravity  and  gravity_p_urea
# Time taken:  0.0030219237009684245
# Entry made in file progress.csv
#
#
#
# Next:  9  of  120 gravity gravity_p_calc
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  8.565584818522135e-05 minutes
# Bipartite Network projected. Time taken:  7.716814676920573e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026541709899902343 minutes
# Model saved
# Done with gravity  and  gravity_p_calc
# Time taken:  0.00300213893254598
# Entry made in file progress.csv
#
#
#
# Next:  10  of  120 gravity osmo_p_cond
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  0.00011295080184936523 minutes
# Bipartite Network projected. Time taken:  3.45150629679362e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027214209238688152 minutes
# Model saved
# Done with gravity  and  osmo_p_cond
# Time taken:  0.0030792713165283202
# Entry made in file progress.csv
#
#
#
# Next:  11  of  120 gravity osmo_p_calc
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  9.70760981241862e-05 minutes
# Bipartite Network projected. Time taken:  3.2341480255126954e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002937491734822591 minutes
# Model saved
# Done with gravity  and  osmo_p_calc
# Time taken:  0.003270308176676432
# Entry made in file progress.csv
#
#
#
# Next:  12  of  120 gravity gravity_p_ph
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  9.951988855997722e-05 minutes
# Bipartite Network projected. Time taken:  8.928775787353516e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002617613474527995 minutes
# Model saved
# Done with gravity  and  gravity_p_ph
# Time taken:  0.0029323538144429523
# Entry made in file progress.csv
#
#
#
# Next:  13  of  120 gravity gravity_p_cond
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  6.520748138427734e-05 minutes
# Bipartite Network projected. Time taken:  2.1990140279134115e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026271263758341473 minutes
# Model saved
# Done with gravity  and  gravity_p_cond
# Time taken:  0.0029419978459676106
# Entry made in file progress.csv
#
#
#
# Next:  14  of  120 gravity cond_p_urea
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  7.110834121704102e-05 minutes
# Bipartite Network projected. Time taken:  1.378456751505534e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027284661928812662 minutes
# Model saved
# Done with gravity  and  cond_p_urea
# Time taken:  0.0030593196551005047
# Entry made in file progress.csv
#
#
#
# Next:  15  of  120 gravity ph_p_cond
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  0.00014095306396484376 minutes
# Bipartite Network projected. Time taken:  3.4519036610921224e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027171651522318522 minutes
# Model saved
# Done with gravity  and  ph_p_cond
# Time taken:  0.003066094716389974
# Entry made in file progress.csv
#
#
#
# Next:  16  of  120 gravity gravity_p_osmo
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  8.736451466878255e-05 minutes
# Bipartite Network projected. Time taken:  7.975101470947266e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026699066162109374 minutes
# Model saved
# Done with gravity  and  gravity_p_osmo
# Time taken:  0.0030414621035257977
# Entry made in file progress.csv
#
#
#
# Next:  17  of  120 gravity ph_p_urea
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  7.33653704325358e-05 minutes
# Bipartite Network projected. Time taken:  1.5171368916829427e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002660520871480306 minutes
# Model saved
# Done with gravity  and  ph_p_urea
# Time taken:  0.0029859066009521483
# Entry made in file progress.csv
#
#
#
# Next:  18  of  120 gravity cond_p_calc
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  0.00010272264480590821 minutes
# Bipartite Network projected. Time taken:  1.3693173726399739e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0025237878163655598 minutes
# Model saved
# Done with gravity  and  cond_p_calc
# Time taken:  0.0028341213862101236
# Entry made in file progress.csv
#
#
#
# Next:  19  of  120 gravity ph_p_calc
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  8.374452590942383e-05 minutes
# Bipartite Network projected. Time taken:  1.4066696166992188e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0019707481066385904 minutes
# Model saved
# Done with gravity  and  ph_p_calc
# Time taken:  0.0022945483525594074
# Entry made in file progress.csv
#
#
#
# Next:  20  of  120 gravity urea_p_calc
# ========================
# No of unique values in  gravity  are:  24
# Bipartite Network created. Time taken:  8.343855539957682e-05 minutes
# Bipartite Network projected. Time taken:  3.086328506469726e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0018855253855387369 minutes
# Model saved
# Done with gravity  and  urea_p_calc
# Time taken:  0.0022078752517700195
# Entry made in file progress.csv
#
#
#
# Next:  21  of  120 ph gravity
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  7.476409276326497e-05 minutes
# Bipartite Network projected. Time taken:  1.817941665649414e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002255400021870931 minutes
# Model saved
# Done with ph  and  gravity
# Time taken:  0.0026195645332336426
# Entry made in file progress.csv
#
#
#
# Next:  22  of  120 ph osmo
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00013272762298583985 minutes
# Bipartite Network projected. Time taken:  5.711714426676432e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0032056212425231934 minutes
# Model saved
# Done with ph  and  osmo
# Time taken:  0.003647764523824056
# Entry made in file progress.csv
#
#
#
# Next:  23  of  120 ph cond
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00012983878453572592 minutes
# Bipartite Network projected. Time taken:  5.42442003885905e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003413561979929606 minutes
# Model saved
# Done with ph  and  cond
# Time taken:  0.003894650936126709
# Entry made in file progress.csv
#
#
#
# Next:  24  of  120 ph urea
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00012369155883789061 minutes
# Bipartite Network projected. Time taken:  5.166530609130859e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003365600109100342 minutes
# Model saved
# Done with ph  and  urea
# Time taken:  0.0038473010063171387
# Entry made in file progress.csv
#
#
#
# Next:  25  of  120 ph calc
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.0001228928565979004 minutes
# Bipartite Network projected. Time taken:  5.4172674814860026e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003472900390625 minutes
# Model saved
# Done with ph  and  calc
# Time taken:  0.003931132952372233
# Entry made in file progress.csv
#
#
#
# Next:  26  of  120 ph ph_p_osmo
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00013437271118164063 minutes
# Bipartite Network projected. Time taken:  3.2611687978108724e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0034197211265563966 minutes
# Model saved
# Done with ph  and  ph_p_osmo
# Time taken:  0.003873280684153239
# Entry made in file progress.csv
#
#
#
# Next:  27  of  120 ph osmo_p_urea
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00011973381042480468 minutes
# Bipartite Network projected. Time taken:  4.678169886271159e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0033897678057352703 minutes
# Model saved
# Done with ph  and  osmo_p_urea
# Time taken:  0.003954041004180908
# Entry made in file progress.csv
#
#
#
# Next:  28  of  120 ph gravity_p_urea
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00020712614059448242 minutes
# Bipartite Network projected. Time taken:  5.054871241251628e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0035695036252339682 minutes
# Model saved
# Done with ph  and  gravity_p_urea
# Time taken:  0.004049539566040039
# Entry made in file progress.csv
#
#
#
# Next:  29  of  120 ph gravity_p_calc
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00012747049331665039 minutes
# Bipartite Network projected. Time taken:  4.991292953491211e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003580820560455322 minutes
# Model saved
# Done with ph  and  gravity_p_calc
# Time taken:  0.004068311055501302
# Entry made in file progress.csv
#
#
#
# Next:  30  of  120 ph osmo_p_cond
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00014923810958862306 minutes
# Bipartite Network projected. Time taken:  5.094607671101888e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0033904751141866046 minutes
# Model saved
# Done with ph  and  osmo_p_cond
# Time taken:  0.0038162946701049806
# Entry made in file progress.csv
#
#
#
# Next:  31  of  120 ph osmo_p_calc
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  9.399255116780599e-05 minutes
# Bipartite Network projected. Time taken:  1.4976660410563152e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027965664863586425 minutes
# Model saved
# Done with ph  and  osmo_p_calc
# Time taken:  0.0031181097030639647
# Entry made in file progress.csv
#
#
#
# Next:  32  of  120 ph gravity_p_ph
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00010573466618855795 minutes
# Bipartite Network projected. Time taken:  2.094109853108724e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002669843037923177 minutes
# Model saved
# Done with ph  and  gravity_p_ph
# Time taken:  0.0030750234921773276
# Entry made in file progress.csv
#
#
#
# Next:  33  of  120 ph gravity_p_cond
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00012567440668741862 minutes
# Bipartite Network projected. Time taken:  2.869764963785807e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002689699331919352 minutes
# Model saved
# Done with ph  and  gravity_p_cond
# Time taken:  0.003054487705230713
# Entry made in file progress.csv
#
#
#
# Next:  34  of  120 ph cond_p_urea
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  6.984074910481771e-05 minutes
# Bipartite Network projected. Time taken:  1.3697147369384766e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002790661652882894 minutes
# Model saved
# Done with ph  and  cond_p_urea
# Time taken:  0.0030165473620096844
# Entry made in file progress.csv
#
#
#
# Next:  35  of  120 ph ph_p_cond
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.00010089874267578125 minutes
# Bipartite Network projected. Time taken:  2.4811426798502603e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0021745761235555014 minutes
# Model saved
# Done with ph  and  ph_p_cond
# Time taken:  0.002558545271555583
# Entry made in file progress.csv
#
#
#
# Next:  36  of  120 ph gravity_p_osmo
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  8.474588394165039e-05 minutes
# Bipartite Network projected. Time taken:  1.5024344126383463e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002056272824605306 minutes
# Model saved
# Done with ph  and  gravity_p_osmo
# Time taken:  0.0023562153180440265
# Entry made in file progress.csv
#
#
#
# Next:  37  of  120 ph ph_p_urea
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  9.575684865315755e-05 minutes
# Bipartite Network projected. Time taken:  7.637341817220052e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0018760800361633302 minutes
# Model saved
# Done with ph  and  ph_p_urea
# Time taken:  0.0021889766057332357
# Entry made in file progress.csv
#
#
#
# Next:  38  of  120 ph cond_p_calc
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  0.0001027981440226237 minutes
# Bipartite Network projected. Time taken:  3.0024846394856772e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0021398385365804036 minutes
# Model saved
# Done with ph  and  cond_p_calc
# Time taken:  0.0024583061536153157
# Entry made in file progress.csv
#
#
#
# Next:  39  of  120 ph ph_p_calc
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  8.128881454467773e-05 minutes
# Bipartite Network projected. Time taken:  7.657210032145182e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0018887758255004884 minutes
# Model saved
# Done with ph  and  ph_p_calc
# Time taken:  0.0022496740023295087
# Entry made in file progress.csv
#
#
#
# Next:  40  of  120 ph urea_p_calc
# ========================
# No of unique values in  ph  are:  25
# Bipartite Network created. Time taken:  8.228619893391927e-05 minutes
# Bipartite Network projected. Time taken:  3.049770991007487e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0019461552302042643 minutes
# Model saved
# Done with ph  and  urea_p_calc
# Time taken:  0.0022642095883687336
# Entry made in file progress.csv
#
#
#
# Next:  41  of  120 osmo gravity
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  7.643302281697591e-05 minutes
# Bipartite Network projected. Time taken:  2.7950604756673177e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0019721150398254394 minutes
# Model saved
# Done with osmo  and  gravity
# Time taken:  0.002276154359181722
# Entry made in file progress.csv
#
#
#
# Next:  42  of  120 osmo ph
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.0001784364382425944 minutes
# Bipartite Network projected. Time taken:  2.3945172627766928e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0020763357480367024 minutes
# Model saved
# Done with osmo  and  ph
# Time taken:  0.0024141867955525718
# Entry made in file progress.csv
#
#
#
# Next:  43  of  120 osmo cond
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  7.658799489339193e-05 minutes
# Bipartite Network projected. Time taken:  1.9518534342447915e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002119159698486328 minutes
# Model saved
# Done with osmo  and  cond
# Time taken:  0.0023783246676127114
# Entry made in file progress.csv
#
#
#
# Next:  44  of  120 osmo urea
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.00012397368748982748 minutes
# Bipartite Network projected. Time taken:  3.07917594909668e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002777552604675293 minutes
# Model saved
# Done with osmo  and  urea
# Time taken:  0.003102572758992513
# Entry made in file progress.csv
#
#
#
# Next:  45  of  120 osmo calc
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  9.002685546875e-05 minutes
# Bipartite Network projected. Time taken:  2.0658969879150392e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027861555417378744 minutes
# Model saved
# Done with osmo  and  calc
# Time taken:  0.0031482577323913574
# Entry made in file progress.csv
#
#
#
# Next:  46  of  120 osmo ph_p_osmo
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  9.179512659708658e-05 minutes
# Bipartite Network projected. Time taken:  8.706251780192057e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0025511582692464194 minutes
# Model saved
# Done with osmo  and  ph_p_osmo
# Time taken:  0.0029486815134684243
# Entry made in file progress.csv
#
#
#
# Next:  47  of  120 osmo osmo_p_urea
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  9.979009628295899e-05 minutes
# Bipartite Network projected. Time taken:  7.2836875915527345e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026370882987976074 minutes
# Model saved
# Done with osmo  and  osmo_p_urea
# Time taken:  0.003067954381306966
# Entry made in file progress.csv
#
#
#
# Next:  48  of  120 osmo gravity_p_urea
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  9.218851725260417e-05 minutes
# Bipartite Network projected. Time taken:  2.3416678110758464e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002625425656636556 minutes
# Model saved
# Done with osmo  and  gravity_p_urea
# Time taken:  0.002991020679473877
# Entry made in file progress.csv
#
#
#
# Next:  49  of  120 osmo gravity_p_calc
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.00010626713434855143 minutes
# Bipartite Network projected. Time taken:  3.141164779663086e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026440103848775227 minutes
# Model saved
# Done with osmo  and  gravity_p_calc
# Time taken:  0.002975773811340332
# Entry made in file progress.csv
#
#
#
# Next:  50  of  120 osmo osmo_p_cond
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.00011795361836751302 minutes
# Bipartite Network projected. Time taken:  8.575121561686198e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002668333053588867 minutes
# Model saved
# Done with osmo  and  osmo_p_cond
# Time taken:  0.0030297120412190754
# Entry made in file progress.csv
#
#
#
# Next:  51  of  120 osmo osmo_p_calc
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.0001019755999247233 minutes
# Bipartite Network projected. Time taken:  2.0281473795572916e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002807792027791341 minutes
# Model saved
# Done with osmo  and  osmo_p_calc
# Time taken:  0.003144244352976481
# Entry made in file progress.csv
#
#
#
# Next:  52  of  120 osmo gravity_p_ph
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.00010424455006917318 minutes
# Bipartite Network projected. Time taken:  1.494884490966797e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027303139368693033 minutes
# Model saved
# Done with osmo  and  gravity_p_ph
# Time taken:  0.003051916758219401
# Entry made in file progress.csv
#
#
#
# Next:  53  of  120 osmo gravity_p_cond
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  6.870826085408529e-05 minutes
# Bipartite Network projected. Time taken:  1.2687842051188151e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002856310208638509 minutes
# Model saved
# Done with osmo  and  gravity_p_cond
# Time taken:  0.003085764249165853
# Entry made in file progress.csv
#
#
#
# Next:  54  of  120 osmo cond_p_urea
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  8.86241594950358e-05 minutes
# Bipartite Network projected. Time taken:  2.3635228474934897e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0028606494267781573 minutes
# Model saved
# Done with osmo  and  cond_p_urea
# Time taken:  0.0031975189844767253
# Entry made in file progress.csv
#
#
#
# Next:  55  of  120 osmo ph_p_cond
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.00010584592819213867 minutes
# Bipartite Network projected. Time taken:  1.5211105346679687e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026117881139119466 minutes
# Model saved
# Done with osmo  and  ph_p_cond
# Time taken:  0.0029525200525919596
# Entry made in file progress.csv
#
#
#
# Next:  56  of  120 osmo gravity_p_osmo
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  9.861389795939128e-05 minutes
# Bipartite Network projected. Time taken:  7.506211598714193e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026124954223632813 minutes
# Model saved
# Done with osmo  and  gravity_p_osmo
# Time taken:  0.002967210610707601
# Entry made in file progress.csv
#
#
#
# Next:  57  of  120 osmo ph_p_urea
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  6.912549336751302e-05 minutes
# Bipartite Network projected. Time taken:  2.4171670277913413e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002788988749186198 minutes
# Model saved
# Done with osmo  and  ph_p_urea
# Time taken:  0.0031128525733947754
# Entry made in file progress.csv
#
#
#
# Next:  58  of  120 osmo cond_p_calc
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  8.758703867594401e-05 minutes
# Bipartite Network projected. Time taken:  1.493692398071289e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026757558186848956 minutes
# Model saved
# Done with osmo  and  cond_p_calc
# Time taken:  0.0030252536137898764
# Entry made in file progress.csv
#
#
#
# Next:  59  of  120 osmo ph_p_calc
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  9.537140528361002e-05 minutes
# Bipartite Network projected. Time taken:  1.618067423502604e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027830084164937336 minutes
# Model saved
# Done with osmo  and  ph_p_calc
# Time taken:  0.0030881404876708985
# Entry made in file progress.csv
#
#
#
# Next:  60  of  120 osmo urea_p_calc
# ========================
# No of unique values in  osmo  are:  26
# Bipartite Network created. Time taken:  0.0001025080680847168 minutes
# Bipartite Network projected. Time taken:  1.3597806294759114e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027359763781229654 minutes
# Model saved
# Done with osmo  and  urea_p_calc
# Time taken:  0.003089157740275065
# Entry made in file progress.csv
#
#
#
# Next:  61  of  120 cond gravity
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  9.788274765014649e-05 minutes
# Bipartite Network projected. Time taken:  3.8115183512369793e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002672910690307617 minutes
# Model saved
# Done with cond  and  gravity
# Time taken:  0.0029935638109842935
# Entry made in file progress.csv
#
#
#
# Next:  62  of  120 cond ph
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  7.813374201456705e-05 minutes
# Bipartite Network projected. Time taken:  2.0352999369303384e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0030583659807840984 minutes
# Model saved
# Done with cond  and  ph
# Time taken:  0.0034374117851257322
# Entry made in file progress.csv
#
#
#
# Next:  63  of  120 cond osmo
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.00015840530395507812 minutes
# Bipartite Network projected. Time taken:  5.1403045654296874e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003670064608256022 minutes
# Model saved
# Done with cond  and  osmo
# Time taken:  0.004284501075744629
# Entry made in file progress.csv
#
#
#
# Next:  64  of  120 cond urea
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  9.371042251586914e-05 minutes
# Bipartite Network projected. Time taken:  3.3672650655110674e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0031389514605204265 minutes
# Model saved
# Done with cond  and  urea
# Time taken:  0.00346455971399943
# Entry made in file progress.csv
#
#
#
# Next:  65  of  120 cond calc
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  9.11871592203776e-05 minutes
# Bipartite Network projected. Time taken:  3.9513905843098955e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026638269424438476 minutes
# Model saved
# Done with cond  and  calc
# Time taken:  0.003004606564839681
# Entry made in file progress.csv
#
#
#
# Next:  66  of  120 cond ph_p_osmo
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  9.588797887166341e-05 minutes
# Bipartite Network projected. Time taken:  0.000101164976755778 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0024701635042826335 minutes
# Model saved
# Done with cond  and  ph_p_osmo
# Time taken:  0.0028727134068806965
# Entry made in file progress.csv
#
#
#
# Next:  67  of  120 cond osmo_p_urea
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  9.248256683349609e-05 minutes
# Bipartite Network projected. Time taken:  4.654725392659505e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002678032716115316 minutes
# Model saved
# Done with cond  and  osmo_p_urea
# Time taken:  0.003100093205769857
# Entry made in file progress.csv
#
#
#
# Next:  68  of  120 cond gravity_p_urea
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.00019011497497558593 minutes
# Bipartite Network projected. Time taken:  4.8955281575520836e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003549949328104655 minutes
# Model saved
# Done with cond  and  gravity_p_urea
# Time taken:  0.004029508431752523
# Entry made in file progress.csv
#
#
#
# Next:  69  of  120 cond gravity_p_calc
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.0001674969991048177 minutes
# Bipartite Network projected. Time taken:  3.288189570109049e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003956810633341471 minutes
# Model saved
# Done with cond  and  gravity_p_calc
# Time taken:  0.004371945063273112
# Entry made in file progress.csv
#
#
#
# Next:  70  of  120 cond osmo_p_cond
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.0001349171002705892 minutes
# Bipartite Network projected. Time taken:  3.702640533447266e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.00248334010442098 minutes
# Model saved
# Done with cond  and  osmo_p_cond
# Time taken:  0.0029817899068196613
# Entry made in file progress.csv
#
#
#
# Next:  71  of  120 cond osmo_p_calc
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.0001624306042989095 minutes
# Bipartite Network projected. Time taken:  4.456043243408203e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026398261388142904 minutes
# Model saved
# Done with cond  and  osmo_p_calc
# Time taken:  0.0031324307123819987
# Entry made in file progress.csv
#
#
#
# Next:  72  of  120 cond gravity_p_ph
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.0001092076301574707 minutes
# Bipartite Network projected. Time taken:  8.613665898640951e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002892013390858968 minutes
# Model saved
# Done with cond  and  gravity_p_ph
# Time taken:  0.0033172170321146646
# Entry made in file progress.csv
#
#
#
# Next:  73  of  120 cond gravity_p_cond
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  8.523861567179362e-05 minutes
# Bipartite Network projected. Time taken:  1.8616517384847004e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0018464883168538412 minutes
# Model saved
# Done with cond  and  gravity_p_cond
# Time taken:  0.0022130330403645833
# Entry made in file progress.csv
#
#
#
# Next:  74  of  120 cond cond_p_urea
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  8.174578348795573e-05 minutes
# Bipartite Network projected. Time taken:  2.7167797088623048e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.001839741071065267 minutes
# Model saved
# Done with cond  and  cond_p_urea
# Time taken:  0.0022376577059427896
# Entry made in file progress.csv
#
#
#
# Next:  75  of  120 cond ph_p_cond
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  8.32358996073405e-05 minutes
# Bipartite Network projected. Time taken:  2.0031134287516276e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0018664280573527019 minutes
# Model saved
# Done with cond  and  ph_p_cond
# Time taken:  0.0022783319155375162
# Entry made in file progress.csv
#
#
#
# Next:  76  of  120 cond gravity_p_osmo
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.00010335048039754232 minutes
# Bipartite Network projected. Time taken:  0.0001355727513631185 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002000558376312256 minutes
# Model saved
# Done with cond  and  gravity_p_osmo
# Time taken:  0.002398693561553955
# Entry made in file progress.csv
#
#
#
# Next:  77  of  120 cond ph_p_urea
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.00010908047358194987 minutes
# Bipartite Network projected. Time taken:  1.5334288279215494e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0029167373975118 minutes
# Model saved
# Done with cond  and  ph_p_urea
# Time taken:  0.0032468676567077638
# Entry made in file progress.csv
#
#
#
# Next:  78  of  120 cond cond_p_calc
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.00017573833465576172 minutes
# Bipartite Network projected. Time taken:  7.053216298421224e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026530941327412923 minutes
# Model saved
# Done with cond  and  cond_p_calc
# Time taken:  0.0031290531158447267
# Entry made in file progress.csv
#
#
#
# Next:  79  of  120 cond ph_p_calc
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  8.517106374104818e-05 minutes
# Bipartite Network projected. Time taken:  2.8161207834879556e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002876122792561849 minutes
# Model saved
# Done with cond  and  ph_p_calc
# Time taken:  0.0032413959503173827
# Entry made in file progress.csv
#
#
#
# Next:  80  of  120 cond urea_p_calc
# ========================
# No of unique values in  cond  are:  26
# Bipartite Network created. Time taken:  0.00010282198588053385 minutes
# Bipartite Network projected. Time taken:  1.6268094380696615e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027535478274027508 minutes
# Model saved
# Done with cond  and  urea_p_calc
# Time taken:  0.003099977970123291
# Entry made in file progress.csv
#
#
#
# Next:  81  of  120 urea gravity
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00010785659154256185 minutes
# Bipartite Network projected. Time taken:  1.958608627319336e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002856608231862386 minutes
# Model saved
# Done with urea  and  gravity
# Time taken:  0.0031468907992045084
# Entry made in file progress.csv
#
#
#
# Next:  82  of  120 urea ph
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  9.526411692301432e-05 minutes
# Bipartite Network projected. Time taken:  2.0150343577067057e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002880386511484782 minutes
# Model saved
# Done with urea  and  ph
# Time taken:  0.0032010912895202638
# Entry made in file progress.csv
#
#
#
# Next:  83  of  120 urea osmo
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  6.279150644938151e-05 minutes
# Bipartite Network projected. Time taken:  2.8777122497558594e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002009312311808268 minutes
# Model saved
# Done with urea  and  osmo
# Time taken:  0.0023660659790039062
# Entry made in file progress.csv
#
#
#
# Next:  84  of  120 urea cond
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  7.661978403727214e-05 minutes
# Bipartite Network projected. Time taken:  1.9216537475585936e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0020076235135396323 minutes
# Model saved
# Done with urea  and  cond
# Time taken:  0.0023299296696980792
# Entry made in file progress.csv
#
#
#
# Next:  85  of  120 urea calc
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00015675624211629232 minutes
# Bipartite Network projected. Time taken:  2.535581588745117e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002046664555867513 minutes
# Model saved
# Done with urea  and  calc
# Time taken:  0.002385556697845459
# Entry made in file progress.csv
#
#
#
# Next:  86  of  120 urea ph_p_osmo
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  8.409420649210611e-05 minutes
# Bipartite Network projected. Time taken:  2.7620792388916014e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002271600564320882 minutes
# Model saved
# Done with urea  and  ph_p_osmo
# Time taken:  0.0026175975799560547
# Entry made in file progress.csv
#
#
#
# Next:  87  of  120 urea osmo_p_urea
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  9.683767954508464e-05 minutes
# Bipartite Network projected. Time taken:  6.8783760070800785e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0020575404167175295 minutes
# Model saved
# Done with urea  and  osmo_p_urea
# Time taken:  0.0025263826052347818
# Entry made in file progress.csv
#
#
#
# Next:  88  of  120 urea gravity_p_urea
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  8.697112401326498e-05 minutes
# Bipartite Network projected. Time taken:  2.0202000935872396e-05 minutes
# Calculating betweenness centrality with k = All nodes
# ...
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0019937316576639813 minutes
# Model saved
# Done with urea  and  gravity_p_calc
# Time taken:  0.0023103992144266764
# Entry made in file progress.csv
#
#
#
# Next:  90  of  120 urea osmo_p_cond
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  9.692509969075521e-05 minutes
# Bipartite Network projected. Time taken:  1.3283888498942058e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0020233790079752603 minutes
# Model saved
# Done with urea  and  osmo_p_cond
# Time taken:  0.002341119448343913
# Entry made in file progress.csv
#
#
#
# Next:  91  of  120 urea osmo_p_calc
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00011481444040934245 minutes
# Bipartite Network projected. Time taken:  1.4571348826090495e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027663588523864748 minutes
# Model saved
# Done with urea  and  osmo_p_calc
# Time taken:  0.0030968546867370605
# Entry made in file progress.csv
#
#
#
# Next:  92  of  120 urea gravity_p_ph
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00014292399088541667 minutes
# Bipartite Network projected. Time taken:  3.316799799601237e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002746693293253581 minutes
# Model saved
# Done with urea  and  gravity_p_ph
# Time taken:  0.0031191746393839518
# Entry made in file progress.csv
#
#
#
# Next:  93  of  120 urea gravity_p_cond
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00014498631159464518 minutes
# Bipartite Network projected. Time taken:  2.384185791015625e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027551611264546713 minutes
# Model saved
# Done with urea  and  gravity_p_cond
# Time taken:  0.003189349174499512
# Entry made in file progress.csv
#
#
#
# Next:  94  of  120 urea cond_p_urea
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00010917981465657552 minutes
# Bipartite Network projected. Time taken:  2.3285547892252605e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002643100420633952 minutes
# Model saved
# Done with urea  and  cond_p_urea
# Time taken:  0.002982012430826823
# Entry made in file progress.csv
#
#
#
# Next:  95  of  120 urea ph_p_cond
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00010211865107218424 minutes
# Bipartite Network projected. Time taken:  2.4024645487467448e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027265191078186036 minutes
# Model saved
# Done with urea  and  ph_p_cond
# Time taken:  0.003126982847849528
# Entry made in file progress.csv
#
#
#
# Next:  96  of  120 urea gravity_p_osmo
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  9.86337661743164e-05 minutes
# Bipartite Network projected. Time taken:  9.397665659586589e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027329762776692706 minutes
# Model saved
# Done with urea  and  gravity_p_osmo
# Time taken:  0.003187231222788493
# Entry made in file progress.csv
#
#
#
# Next:  97  of  120 urea ph_p_urea
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  9.376207987467448e-05 minutes
# Bipartite Network projected. Time taken:  1.1269251505533854e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027506073315938314 minutes
# Model saved
# Done with urea  and  ph_p_urea
# Time taken:  0.0030226945877075196
# Entry made in file progress.csv
#
#
#
# Next:  98  of  120 urea cond_p_calc
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  8.336305618286132e-05 minutes
# Bipartite Network projected. Time taken:  3.478129704793294e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002729841073354085 minutes
# Model saved
# Done with urea  and  cond_p_calc
# Time taken:  0.0030819177627563477
# Entry made in file progress.csv
#
#
#
# Next:  99  of  120 urea ph_p_calc
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  0.00010597308476765951 minutes
# Bipartite Network projected. Time taken:  4.011392593383789e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027564803759257 minutes
# Model saved
# Done with urea  and  ph_p_calc
# Time taken:  0.0031130194664001467
# Entry made in file progress.csv
#
#
#
# Next:  100  of  120 urea urea_p_calc
# ========================
# No of unique values in  urea  are:  26
# Bipartite Network created. Time taken:  8.284250895182291e-05 minutes
# Bipartite Network projected. Time taken:  8.424123128255209e-06 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0025993744532267255 minutes
# Model saved
# Done with urea  and  urea_p_calc
# Time taken:  0.002981885274251302
# Entry made in file progress.csv
#
#
#
# Next:  101  of  120 calc gravity
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  9.888013203938802e-05 minutes
# Bipartite Network projected. Time taken:  3.147522608439128e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0028154174486796062 minutes
# Model saved
# Done with calc  and  gravity
# Time taken:  0.003137505054473877
# Entry made in file progress.csv
#
#
#
# Next:  102  of  120 calc ph
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  8.12371571858724e-05 minutes
# Bipartite Network projected. Time taken:  1.7766157786051432e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002848660945892334 minutes
# Model saved
# Done with calc  and  ph
# Time taken:  0.0031809488932291667
# Entry made in file progress.csv
#
#
#
# Next:  103  of  120 calc osmo
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  8.584260940551758e-05 minutes
# Bipartite Network projected. Time taken:  1.7130374908447264e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027965545654296876 minutes
# Model saved
# Done with calc  and  osmo
# Time taken:  0.0031312942504882813
# Entry made in file progress.csv
#
#
#
# Next:  104  of  120 calc cond
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  9.92894172668457e-05 minutes
# Bipartite Network projected. Time taken:  3.451108932495117e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027853051821390786 minutes
# Model saved
# Done with calc  and  cond
# Time taken:  0.0031203826268514
# Entry made in file progress.csv
#
#
#
# Next:  105  of  120 calc urea
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  8.787314097086588e-05 minutes
# Bipartite Network projected. Time taken:  3.003676732381185e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003794741630554199 minutes
# Model saved
# Done with calc  and  urea
# Time taken:  0.004214576880137126
# Entry made in file progress.csv
#
#
#
# Next:  106  of  120 calc ph_p_osmo
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00010248025258382161 minutes
# Bipartite Network projected. Time taken:  2.3098786671956382e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003451371192932129 minutes
# Model saved
# Done with calc  and  ph_p_osmo
# Time taken:  0.0037916024525960286
# Entry made in file progress.csv
#
#
#
# Next:  107  of  120 calc osmo_p_urea
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00014243523279825845 minutes
# Bipartite Network projected. Time taken:  4.5911471048990885e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0035049796104431154 minutes
# Model saved
# Done with calc  and  osmo_p_urea
# Time taken:  0.0039943337440490724
# Entry made in file progress.csv
#
#
#
# Next:  108  of  120 calc gravity_p_urea
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00016698837280273437 minutes
# Bipartite Network projected. Time taken:  5.386273066202799e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003441774845123291 minutes
# Model saved
# Done with calc  and  gravity_p_urea
# Time taken:  0.003962882359822591
# Entry made in file progress.csv
#
#
#
# Next:  109  of  120 calc gravity_p_calc
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  9.64204470316569e-05 minutes
# Bipartite Network projected. Time taken:  4.375775655110677e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003245703379313151 minutes
# Model saved
# Done with calc  and  gravity_p_calc
# Time taken:  0.0037354667981465656
# Entry made in file progress.csv
#
#
#
# Next:  110  of  120 calc osmo_p_cond
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.0001079559326171875 minutes
# Bipartite Network projected. Time taken:  8.060137430826823e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003514409065246582 minutes
# Model saved
# Done with calc  and  osmo_p_cond
# Time taken:  0.004036017258961995
# Entry made in file progress.csv
#
#
#
# Next:  111  of  120 calc osmo_p_calc
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.0001854737599690755 minutes
# Bipartite Network projected. Time taken:  3.8119157155354816e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.003596850236256917 minutes
# Model saved
# Done with calc  and  osmo_p_calc
# Time taken:  0.004092808564503988
# Entry made in file progress.csv
#
#
#
# Next:  112  of  120 calc gravity_p_ph
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00016659100850423177 minutes
# Bipartite Network projected. Time taken:  4.6586990356445314e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0038062294324239096 minutes
# Model saved
# Done with calc  and  gravity_p_ph
# Time taken:  0.004299513498942057
# Entry made in file progress.csv
#
#
#
# Next:  113  of  120 calc gravity_p_cond
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00021708011627197266 minutes
# Bipartite Network projected. Time taken:  4.739761352539063e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0035786827405293784 minutes
# Model saved
# Done with calc  and  gravity_p_cond
# Time taken:  0.004068732261657715
# Entry made in file progress.csv
#
#
#
# Next:  114  of  120 calc cond_p_urea
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  9.061098098754883e-05 minutes
# Bipartite Network projected. Time taken:  2.9039382934570312e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002704024314880371 minutes
# Model saved
# Done with calc  and  cond_p_urea
# Time taken:  0.0030370354652404785
# Entry made in file progress.csv
#
#
#
# Next:  115  of  120 calc ph_p_cond
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00010628302892049154 minutes
# Bipartite Network projected. Time taken:  1.4917055765787761e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027866482734680174 minutes
# Model saved
# Done with calc  and  ph_p_cond
# Time taken:  0.003105175495147705
# Entry made in file progress.csv
#
#
#
# Next:  116  of  120 calc gravity_p_osmo
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  6.841023763020833e-05 minutes
# Bipartite Network projected. Time taken:  1.4527638753255208e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0026373863220214844 minutes
# Model saved
# Done with calc  and  gravity_p_osmo
# Time taken:  0.0029957811037699383
# Entry made in file progress.csv
#
#
#
# Next:  117  of  120 calc ph_p_urea
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00010455846786499024 minutes
# Bipartite Network projected. Time taken:  3.0374526977539064e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0027607162793477375 minutes
# Model saved
# Done with calc  and  ph_p_urea
# Time taken:  0.0030881047248840334
# Entry made in file progress.csv
#
#
#
# Next:  118  of  120 calc cond_p_calc
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00011457999547322591 minutes
# Bipartite Network projected. Time taken:  1.092354456583659e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002799657980600993 minutes
# Model saved
# Done with calc  and  cond_p_calc
# Time taken:  0.0031206647555033365
# Entry made in file progress.csv
#
#
#
# Next:  119  of  120 calc ph_p_calc
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  0.00011782646179199218 minutes
# Bipartite Network projected. Time taken:  1.8346309661865235e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.0025353153546651204 minutes
# Model saved
# Done with calc  and  ph_p_calc
# Time taken:  0.002871982256571452
# Entry made in file progress.csv
#
#
#
# Next:  120  of  120 calc urea_p_calc
# ========================
# No of unique values in  calc  are:  24
# Bipartite Network created. Time taken:  9.896357854207356e-05 minutes
# Bipartite Network projected. Time taken:  2.710421880086263e-05 minutes
# Calculating betweenness centrality with k = All nodes
# Betweenness centrality calculated
# Model extracted. Time taken:  0.002586996555328369 minutes
# Model saved
# Done with calc  and  urea_p_calc
# Time taken:  0.0029574473698933917
# Entry made in file progress.csv
# CatEncodersFamily(cMeasures=[1, 1, 1, 1, None, 1, 1],
#                   pathToStoreProgress=PosixPath('/content/allmodels/progress'))

# %% [markdown]
# ## Data transformation:

# %%
# 6.0 Transform both test_binned and train_binned data:

test_trans = ct.transform(test_binned)

f"Transformed test data shape: {test_trans.shape}"
# Out:
# ====Reading all model-dicts from RAM
#
#
# ====All saved model-dicts read! Model files are intact!
# ====Total model-dict are:  600
# ====Sending model loading progress to file: /content/allmodels/progress/load_stored_models.txt
# When loading is in progress, open this file with notepad++ AND NOT with notepad
#
#
# Current mem usage is: 0.165886 MB
# Mem usage after dtype transformation is: 0.087166 MB
# 'Transformed test data shape: (41, 486)'

# %%
# 6.0.1 Transform train_binned now:

train_trans= ct.transform(train_binned[cat_cols])

f"Transformed train data shape: {train_trans.shape}"
# Out:
# ====Reading all model-dicts from RAM
#
#
# ====All saved model-dicts read! Model files are intact!
# ====Total model-dict are:  600
# ====Sending model loading progress to file: /content/allmodels/progress/load_stored_models.txt
# When loading is in progress, open this file with notepad++ AND NOT with notepad
#
#
# Current mem usage is: 1.445414 MB
# Mem usage after dtype transformation is: 0.729254 MB
# 'Transformed train data shape: (373, 486)'

# %% [markdown]
# Our new features are substantially difft from original features. Prefixes to feature names imply as below:
# <i>
# >deg_ ===> This feature results from calculation of degree centrality<br>
# >eig_ ===> This feature results from calculation of eigenvector centrality<br>
# >pr_  ===> This feature results from calculation of page rank centrality<br>
# >bet_ ===> This feature results from calculation of betweenness centrality<br>
# >clu_ ===> This feature results from calculation of clustering characteristics<br>,</i>

# %%
# 6.1 Observe data now:
#     It also has original binned cols (5):

train_trans.head()
test_trans.head()
# Out:
#   gravity   ph  osmo  cond  urea  calc  deg_gravity_ck_ph  eig_gravity_ck_ph  \
# 0     414  813  1221  1617  2022   245           0.956522           0.225274
# 1      46   89   128  1612  2010   245           0.956522           0.225274
# 2     414   88  1214  1617  2011   245           0.956522           0.225274
# 3     412   88  1217  1619  2017   245           0.913043           0.219592
# 4      43  812  1217  1612  2021  2415           0.956522           0.221688
#
#    pr_gravity_ck_ph  clu_gravity_ck_ph  ...  clu_calc_ck_gravity_p_osmo  \
# 0          0.046688           0.887446  ...                    0.521053
# 1          0.046688           0.887446  ...                    0.521053
# 2          0.046688           0.887446  ...                    0.521053
# 3          0.044657           0.928571  ...                    0.521053
# 4          0.047518           0.857143  ...                    0.594771
#
#    bet_calc_ck_gravity_p_osmo  deg_calc_ck_ph_p_urea  eig_calc_ck_ph_p_urea  \
# 0                    0.096681               0.695652               0.303425
# 1                    0.096681               0.695652               0.303425
# 2                    0.096681               0.695652               0.303425
# 3                    0.096681               0.695652               0.303425
# 4                    0.051490               0.826087               0.323787
#
#    pr_calc_ck_ph_p_urea  clu_calc_ck_ph_p_urea  bet_calc_ck_ph_p_urea  \
# 0              0.069933               0.533333               0.065891
# 1              0.069933               0.533333               0.065891
# 2              0.069933               0.533333               0.065891
# 3              0.069933               0.533333               0.065891
# 4              0.091283               0.415205               0.244120
#
#    eig_calc_ck_cond_p_calc  eig_calc_ck_ph_p_calc  eig_calc_ck_urea_p_calc
# 0                -0.066081               0.128041                 0.011655
# 1                -0.066081               0.128041                 0.011655
# 2                -0.066081               0.128041                 0.011655
# 3                -0.066081               0.128041                 0.011655
# 4                -0.188992              -0.081565                -0.336905
#
# [5 rows x 486 columns]
#   gravity   ph  osmo  cond  urea  calc  deg_gravity_ck_ph  eig_gravity_ck_ph  \
# 0      47  814   128   169   206   243           0.913043           0.217098
# 1     418   87  1215  1617  2019   249           0.956522           0.225274
# 2      44  813   126  1618   208  2419           0.739130           0.182436
# 3     414   82   128  1615  2020  2414           0.956522           0.225274
# 4     414   88  1220  1612  2019   245           0.956522           0.225274
#
#    pr_gravity_ck_ph  clu_gravity_ck_ph  ...  clu_calc_ck_gravity_p_osmo  \
# 0          0.044798           0.904762  ...                    0.583333
# 1          0.046688           0.887446  ...                    0.685714
# 2          0.037197           0.970588  ...                    0.717949
# 3          0.046688           0.887446  ...                    0.785714
# 4          0.046688           0.887446  ...                    0.521053
#
#    bet_calc_ck_gravity_p_osmo  deg_calc_ck_ph_p_urea  eig_calc_ck_ph_p_urea  \
# 0                    0.054161               0.652174               0.295473
# 1                    0.023325               0.347826               0.170278
# 2                    0.027015               0.347826               0.165397
# 3                    0.004216               0.217391               0.124458
# 4                    0.096681               0.695652               0.303425
#
#    pr_calc_ck_ph_p_urea  clu_calc_ck_ph_p_urea  bet_calc_ck_ph_p_urea  \
# 0              0.065505               0.580952               0.045542
# 1              0.038035               0.714286               0.012368
# 2              0.038112               0.750000               0.010380
# 3              0.025482               0.900000               0.000494
# 4              0.069933               0.533333               0.065891
#
#    eig_calc_ck_cond_p_calc  eig_calc_ck_ph_p_calc  eig_calc_ck_urea_p_calc
# 0                -0.133384               0.314369                -0.265196
# 1                 0.020903              -0.003133                -0.195072
# 2                 0.144902              -0.244948                -0.140478
# 3                 0.238525               0.219477                -0.275341
# 4                -0.066081               0.128041                 0.011655
#
# [5 rows x 486 columns]

# %%
# 6.2 Pop out target:

_= orig_train.pop('target')
_= orig_test.pop('target')

# %% [markdown]
# ## PCA with original data and transformed data:

# %%
# 7.0 PCA with original train data:

pca = PCA(n_components = 2,  whiten= True, random_state= None)
ss= StandardScaler()
orig_pca = pca.fit_transform(ss.fit_transform(orig_train[cat_cols]))
orig_pca.shape
# Out:
# (373, 2)

# %%
# 7.1 PCA with transformed train data.
#     Drop the five cat_cols first:

trans_pca = train_trans.iloc[:,len(cat_cols):]
trans_pca.isnull().sum().sum()  # If not null perform imputation with SimpleImputer(strategy = 'median')
# Out:
# 0

# %%
# 7.2 PCA of transformed data:

pca = PCA(n_components= 2, whiten= True, random_state = None)
ss = StandardScaler()
trans_pca = pca.fit_transform(ss.fit_transform(trans_pca))
trans_pca.shape
# Out:
# (373, 2)

# %%
# 7.3 Assign column names;

colnames = ["pc" + str(i) for i in range(orig_pca.shape[1])]
orig_pca  = pd.DataFrame(orig_pca, columns = colnames)
trans_pca = pd.DataFrame(trans_pca, columns = colnames)

# %%
# 8.1 PCA from original train data:

plt.style.use("dark_background")
sns.scatterplot(data = orig_pca ,
                x= 'pc0',
                y = 'pc1',
                hue = ytr.values,
                palette = ["#33cc33", "#cc0000"]
                ).set(title='PCA of original numeric data');

# %%
# 8.2 PCA from transformed data:

plt.style.use("dark_background")
sns.scatterplot(data = trans_pca,
                x= 'pc0',
                y = 'pc1',
                hue = ytr.values,
                palette = ["#33cc33", "#cc0000"]
                ).set(title='PCA from transformed data') ;

# %% [markdown]
# ## xgboost modeling:

# %%
# 9.0 Original train/test data:

evals_result= {}
model_orig = xgb.XGBClassifier( n_estimators= 200,
                               verbosity = 3,
                               eta = 0.06,      
                               max_depth = 6,
                               subsample = 0.8, 
                               evals_result = evals_result,
                               random_state = None,
                              )


tr_X =   orig_train
test_X = orig_test
ytr = ytr 
yte = yte 


model_orig.fit(tr_X, ytr.values,             
               early_stopping_rounds = 50,   
               eval_set=[ (tr_X, ytr.values), (test_X, yte.values)], 
               eval_metric = ['auc']        
              )
# Out:
# [19:28:44] WARNING: ../src/learner.cc:767:
# Parameters: { "evals_result" } are not used.
#
# [19:28:44] DEBUG: ../src/gbm/gbtree.cc:157: Using tree method: 2
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [0]	validation_0-auc:0.86501	validation_1-auc:0.73016
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [1]	validation_0-auc:0.90923	validation_1-auc:0.78439
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [2]	validation_0-auc:0.91678	validation_1-auc:0.78175
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [3]	validation_0-auc:0.92669	validation_1-auc:0.78042
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [4]	validation_0-auc:0.92764	validation_1-auc:0.76852
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [5]	validation_0-auc:0.92993	validation_1-auc:0.76323
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [6]	validation_0-auc:0.93289	validation_1-auc:0.74735
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [7]	validation_0-auc:0.93017	validation_1-auc:0.76323
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [8]	validation_0-auc:0.93122	validation_1-auc:0.76058
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [9]	validation_0-auc:0.93377	validation_1-auc:0.75000
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [10]	validation_0-auc:0.93560	validation_1-auc:0.75794
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [11]	validation_0-auc:0.93950	validation_1-auc:0.75000
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=6
# [12]	validation_0-auc:0.94318	validation_1-auc:0.75000
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [13]	validation_0-auc:0.94405	validation_1-auc:0.74868
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [14]	validation_0-auc:0.94835	validation_1-auc:0.75000
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [15]	validation_0-auc:0.94844	validation_1-auc:0.75529
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [16]	validation_0-auc:0.94993	validation_1-auc:0.76323
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [17]	validation_0-auc:0.95216	validation_1-auc:0.76058
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [18]	validation_0-auc:0.95088	validation_1-auc:0.75794
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=6
# [19]	validation_0-auc:0.95413	validation_1-auc:0.75529
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [20]	validation_0-auc:0.95465	validation_1-auc:0.75265
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [21]	validation_0-auc:0.95607	validation_1-auc:0.74206
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [22]	validation_0-auc:0.95833	validation_1-auc:0.74471
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [23]	validation_0-auc:0.96021	validation_1-auc:0.75000
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [24]	validation_0-auc:0.96074	validation_1-auc:0.75529
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [25]	validation_0-auc:0.96187	validation_1-auc:0.75265
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=6
# [26]	validation_0-auc:0.96352	validation_1-auc:0.75794
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=6
# [27]	validation_0-auc:0.96431	validation_1-auc:0.76323
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [28]	validation_0-auc:0.96492	validation_1-auc:0.75794
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [29]	validation_0-auc:0.96657	validation_1-auc:0.76058
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [30]	validation_0-auc:0.96750	validation_1-auc:0.75794
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [31]	validation_0-auc:0.96810	validation_1-auc:0.75529
# [19:28:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=6
# [32]	validation_0-auc:0.96850	validation_1-auc:0.75529
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [33]	validation_0-auc:0.96873	validation_1-auc:0.74735
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=6
# [34]	validation_0-auc:0.97007	validation_1-auc:0.74735
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [35]	validation_0-auc:0.97007	validation_1-auc:0.73942
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [36]	validation_0-auc:0.97036	validation_1-auc:0.74471
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [37]	validation_0-auc:0.97210	validation_1-auc:0.74735
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [38]	validation_0-auc:0.97224	validation_1-auc:0.75265
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [39]	validation_0-auc:0.97328	validation_1-auc:0.75265
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [40]	validation_0-auc:0.97334	validation_1-auc:0.75794
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=6
# [41]	validation_0-auc:0.97522	validation_1-auc:0.76058
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [42]	validation_0-auc:0.97604	validation_1-auc:0.75529
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [43]	validation_0-auc:0.97737	validation_1-auc:0.75794
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [44]	validation_0-auc:0.97801	validation_1-auc:0.75794
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=6
# [45]	validation_0-auc:0.97772	validation_1-auc:0.75794
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [46]	validation_0-auc:0.97783	validation_1-auc:0.76323
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [47]	validation_0-auc:0.97806	validation_1-auc:0.76323
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [48]	validation_0-auc:0.97818	validation_1-auc:0.75794
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=6
# [49]	validation_0-auc:0.97914	validation_1-auc:0.76323
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [50]	validation_0-auc:0.97911	validation_1-auc:0.76323
# [19:28:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [19:28:45] ======== Monitor (0): Learner ========
# [19:28:45] Configure: 0.000993s, 1 calls @ 993us
#
# [19:28:45] EvalOneIter: 0.025792s, 52 calls @ 25792us
#
# [19:28:45] GetGradient: 0.050286s, 52 calls @ 50286us
#
# [19:28:45] PredictRaw: 0.000282s, 52 calls @ 282us
#
# [19:28:45] UpdateOneIter: 0.170467s, 52 calls @ 170467us
#
# [19:28:45] ======== Monitor (0): GBTree ========
# [19:28:45] BoostNewTrees: 0.115675s, 52 calls @ 115675us
#
# [19:28:45] CommitModel: 6.9e-05s, 52 calls @ 69us
#
# [19:28:45] ======== Monitor (0): TreePruner ========
# [19:28:45] PrunerUpdate: 0.065696s, 52 calls @ 65696us
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.06, eval_metric=None,
#               evals_result={}, feature_types=None, gamma=None, gpu_id=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=None, num_parallel_tree=None, ...)

# %%
# 9.1 Scores:

f"Best auc from orig train/test data: {model_orig.best_score}"
print("\n===========\n")
f"Best iteration from orig train/test data: {model_orig.best_iteration}"
# Out:
# 'Best auc from orig train/test data: 0.7843915343915344'
# ===========
# 'Best iteration from orig train/test data: 1'

# %%
# 9.2 Modeling with transformed train/test data:

evals_result= {}
model_trans = xgb.XGBClassifier( n_estimators= 300,
                           verbosity = 3,
                           eta = 0.06,      
                           max_depth = 14,
                           subsample = 0.9,        
                           evals_result = evals_result,
                           random_state = None,
                           )


tr_X =   train_trans.iloc[:,len(cat_cols):]
test_X = test_trans.iloc[:,len(cat_cols):]
ytr = ytr 
yte = yte 


model_trans.fit(tr_X, ytr.values,     
          early_stopping_rounds = 100, 
          eval_set=[ (tr_X, ytr.values), (test_X, yte.values)],
          eval_metric = ['auc']    
          )
# Out:
# [19:28:02] WARNING: ../src/learner.cc:767:
# Parameters: { "evals_result" } are not used.
#
# [19:28:02] DEBUG: ../src/gbm/gbtree.cc:157: Using tree method: 2
# [19:28:02] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 68 extra nodes, 0 pruned nodes, max_depth=10
# [0]	validation_0-auc:0.95552	validation_1-auc:0.60979
# [19:28:02] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=11
# [1]	validation_0-auc:0.97864	validation_1-auc:0.64286
# [19:28:03] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=9
# [2]	validation_0-auc:0.98022	validation_1-auc:0.65344
# [19:28:03] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=8
# [3]	validation_0-auc:0.98590	validation_1-auc:0.67725
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=9
# [4]	validation_0-auc:0.98796	validation_1-auc:0.65608
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=7
# [5]	validation_0-auc:0.99339	validation_1-auc:0.63757
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=7
# [6]	validation_0-auc:0.99623	validation_1-auc:0.67196
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=9
# [7]	validation_0-auc:0.99577	validation_1-auc:0.67196
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=8
# [8]	validation_0-auc:0.99681	validation_1-auc:0.65079
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=9
# [9]	validation_0-auc:0.99748	validation_1-auc:0.67989
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=8
# [10]	validation_0-auc:0.99719	validation_1-auc:0.67460
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=9
# [11]	validation_0-auc:0.99748	validation_1-auc:0.67460
# [19:28:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=7
# [12]	validation_0-auc:0.99794	validation_1-auc:0.66138
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=8
# [13]	validation_0-auc:0.99826	validation_1-auc:0.67196
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=9
# [14]	validation_0-auc:0.99841	validation_1-auc:0.66667
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=8
# [15]	validation_0-auc:0.99846	validation_1-auc:0.67196
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=8
# [16]	validation_0-auc:0.99858	validation_1-auc:0.66667
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=10
# [17]	validation_0-auc:0.99881	validation_1-auc:0.65873
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=8
# [18]	validation_0-auc:0.99904	validation_1-auc:0.66138
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=10
# [19]	validation_0-auc:0.99907	validation_1-auc:0.66402
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=9
# [20]	validation_0-auc:0.99904	validation_1-auc:0.65344
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=11
# [21]	validation_0-auc:0.99907	validation_1-auc:0.65079
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 60 extra nodes, 0 pruned nodes, max_depth=8
# [22]	validation_0-auc:0.99933	validation_1-auc:0.65873
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 58 extra nodes, 0 pruned nodes, max_depth=10
# [23]	validation_0-auc:0.99959	validation_1-auc:0.65344
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=8
# [24]	validation_0-auc:0.99959	validation_1-auc:0.65079
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=10
# [25]	validation_0-auc:0.99965	validation_1-auc:0.66402
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=7
# [26]	validation_0-auc:0.99971	validation_1-auc:0.65873
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=7
# [27]	validation_0-auc:0.99977	validation_1-auc:0.65873
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=9
# [28]	validation_0-auc:0.99983	validation_1-auc:0.65344
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=10
# [29]	validation_0-auc:0.99986	validation_1-auc:0.65873
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=7
# [30]	validation_0-auc:0.99994	validation_1-auc:0.65873
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=11
# [31]	validation_0-auc:0.99997	validation_1-auc:0.65608
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=8
# [32]	validation_0-auc:0.99997	validation_1-auc:0.65608
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=8
# [33]	validation_0-auc:0.99997	validation_1-auc:0.67460
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 54 extra nodes, 0 pruned nodes, max_depth=8
# [34]	validation_0-auc:0.99997	validation_1-auc:0.67460
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 56 extra nodes, 0 pruned nodes, max_depth=9
# [35]	validation_0-auc:0.99997	validation_1-auc:0.67460
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=8
# [36]	validation_0-auc:0.99997	validation_1-auc:0.68254
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=13
# [37]	validation_0-auc:0.99997	validation_1-auc:0.69048
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=7
# [38]	validation_0-auc:0.99997	validation_1-auc:0.69577
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=9
# [39]	validation_0-auc:0.99997	validation_1-auc:0.69841
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=7
# [40]	validation_0-auc:0.99997	validation_1-auc:0.69048
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=8
# [41]	validation_0-auc:0.99997	validation_1-auc:0.69577
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=9
# [42]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=9
# [43]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=7
# [44]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=8
# [45]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=8
# [46]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 48 extra nodes, 0 pruned nodes, max_depth=9
# [47]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=7
# [48]	validation_0-auc:1.00000	validation_1-auc:0.68519
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=8
# [49]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=7
# [50]	validation_0-auc:1.00000	validation_1-auc:0.68783
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=11
# [51]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=7
# [52]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=8
# [53]	validation_0-auc:1.00000	validation_1-auc:0.68783
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=10
# [54]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=7
# [55]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=7
# [56]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=10
# [57]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=7
# [58]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=7
# [59]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 40 extra nodes, 0 pruned nodes, max_depth=9
# [60]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=6
# [61]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [62]	validation_0-auc:1.00000	validation_1-auc:0.68519
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=7
# [63]	validation_0-auc:1.00000	validation_1-auc:0.69048
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=6
# [64]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=7
# [65]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [66]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=8
# [67]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=5
# [68]	validation_0-auc:1.00000	validation_1-auc:0.70370
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=7
# [69]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=7
# [70]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=8
# [71]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=9
# [72]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=5
# [73]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=9
# [74]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [75]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=5
# [76]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=7
# [77]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=7
# [78]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=5
# [79]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=7
# [80]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=7
# [81]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=10
# [82]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [83]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=5
# [84]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=4
# [85]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=6
# [86]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=8
# [87]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=7
# [88]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=7
# [89]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=8
# [90]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=7
# [91]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=5
# [92]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=6
# [93]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [94]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=7
# [95]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=7
# [96]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=5
# [97]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [98]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [99]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=6
# [100]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=8
# [101]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=7
# [102]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [103]	validation_0-auc:1.00000	validation_1-auc:0.70370
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=9
# [104]	validation_0-auc:1.00000	validation_1-auc:0.70370
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [105]	validation_0-auc:1.00000	validation_1-auc:0.70370
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=5
# [106]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=5
# [107]	validation_0-auc:1.00000	validation_1-auc:0.70370
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=7
# [108]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=7
# [109]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [110]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [111]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [112]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=6
# [113]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=7
# [114]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=6
# [115]	validation_0-auc:1.00000	validation_1-auc:0.70635
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=5
# [116]	validation_0-auc:1.00000	validation_1-auc:0.70370
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=7
# [117]	validation_0-auc:1.00000	validation_1-auc:0.70106
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=7
# [118]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [119]	validation_0-auc:1.00000	validation_1-auc:0.69312
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=7
# [120]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=5
# [121]	validation_0-auc:1.00000	validation_1-auc:0.69577
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [122]	validation_0-auc:1.00000	validation_1-auc:0.69841
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [123]	validation_0-auc:1.00000	validation_1-auc:0.70370
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [124]	validation_0-auc:1.00000	validation_1-auc:0.70635
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [125]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=5
# [126]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [127]	validation_0-auc:1.00000	validation_1-auc:0.70899
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=5
# [128]	validation_0-auc:1.00000	validation_1-auc:0.70899
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=5
# [129]	validation_0-auc:1.00000	validation_1-auc:0.70899
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [130]	validation_0-auc:1.00000	validation_1-auc:0.70635
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [131]	validation_0-auc:1.00000	validation_1-auc:0.70899
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=7
# [132]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [133]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=7
# [134]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [135]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [136]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [137]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=6
# [138]	validation_0-auc:1.00000	validation_1-auc:0.72222
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [139]	validation_0-auc:1.00000	validation_1-auc:0.72222
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [140]	validation_0-auc:1.00000	validation_1-auc:0.72222
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [141]	validation_0-auc:1.00000	validation_1-auc:0.72222
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=6
# [142]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=7
# [143]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [144]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [145]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [146]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [147]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [148]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=7
# [149]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=7
# [150]	validation_0-auc:1.00000	validation_1-auc:0.72222
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [151]	validation_0-auc:1.00000	validation_1-auc:0.72222
# [19:28:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=7
# [152]	validation_0-auc:1.00000	validation_1-auc:0.72222
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [153]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [154]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [155]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [156]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=7
# [157]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [158]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [159]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [160]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [161]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [162]	validation_0-auc:1.00000	validation_1-auc:0.71958
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [163]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [164]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=6
# [165]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [166]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [167]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=7
# [168]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [169]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# [170]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=5
# [171]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [172]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=6
# [173]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [174]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [175]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [176]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [177]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [178]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=6
# [179]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [180]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [181]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=6
# [182]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [183]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [184]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [185]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [186]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=6
# [187]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [188]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [189]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [190]	validation_0-auc:1.00000	validation_1-auc:0.71693
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [191]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [192]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [193]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=6
# [194]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [195]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [196]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [197]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [198]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [199]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [200]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [201]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [202]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [203]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [204]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=6
# [205]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [206]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [207]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [208]	validation_0-auc:1.00000	validation_1-auc:0.70899
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [209]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [210]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=6
# [211]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [212]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=6
# [213]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [214]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [215]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [216]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [217]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [218]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [219]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=5
# [220]	validation_0-auc:1.00000	validation_1-auc:0.70635
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [221]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [222]	validation_0-auc:1.00000	validation_1-auc:0.70899
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [223]	validation_0-auc:1.00000	validation_1-auc:0.70899
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [224]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [225]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [226]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [227]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [228]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [229]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [230]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [231]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=5
# [232]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [233]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [234]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [235]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [236]	validation_0-auc:1.00000	validation_1-auc:0.71164
# [19:28:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [237]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [238]	validation_0-auc:1.00000	validation_1-auc:0.71429
# [19:28:11] ======== Monitor (0): Learner ========
# [19:28:11] Configure: 0.002114s, 1 calls @ 2114us
#
# [19:28:11] EvalOneIter: 0.541496s, 239 calls @ 541496us
#
# [19:28:11] GetGradient: 0.131196s, 239 calls @ 131196us
#
# [19:28:11] PredictRaw: 0.0014s, 239 calls @ 1400us
#
# [19:28:11] UpdateOneIter: 5.95683s, 239 calls @ 5956835us
#
# [19:28:11] ======== Monitor (0): GBTree ========
# [19:28:11] BoostNewTrees: 5.81245s, 239 calls @ 5812454us
#
# [19:28:11] CommitModel: 0.000285s, 239 calls @ 285us
#
# [19:28:11] ======== Monitor (0): TreePruner ========
# [19:28:11] PrunerUpdate: 0.316449s, 239 calls @ 316449us
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.06, eval_metric=None,
#               evals_result={}, feature_types=None, gamma=None, gpu_id=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=14, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=300, n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Learning curve plots

# %%
# 9.3 Modeling with original data:

# Ref: https://stackoverflow.com/a/60366515
results = model_orig.evals_result()
epochs = len(results['validation_0']['auc'])
x_axis = range(0, epochs)
fig, ax = plt.subplots();
ax.plot(x_axis, results['validation_0']['auc'], label='Train');
ax.plot(x_axis, results['validation_1']['auc'], label='Test');
ax.legend();
plt.ylabel('AUC');
plt.title('XGBoost AUC--Original data');
plt.show();

# %%
# 9.4 Modeling with transformed data:

results = model_trans.evals_result()
epochs = len(results['validation_0']['auc'])
x_axis = range(0, epochs)
fig, ax = plt.subplots();
ax.plot(x_axis, results['validation_0']['auc'], label='Train');
ax.plot(x_axis, results['validation_1']['auc'], label='Test');
ax.legend();
plt.ylabel('AUC');
plt.title('XGBoost AUC--Transformed data');
plt.show();

# %%
# 9.5
f"Best auc from transformed train/test data: {model_trans.best_score}"
print("\n===========\n")
f"Best iteration from transformed train/test data: {model_trans.best_iteration}"
# Out:
# 'Best auc from transformed train/test data: 0.7301587301587301'
# ===========
# 'Best iteration from transformed train/test data: 281'

# %% [markdown]
# ## Feature importance
# Extract feature importance using function `utils.xgImptFeatures()`. The function outputs three objects as follows::
# >`fe_1`: List of columns arranged in order of descending xgboost impt(feat-impt >0)<br>
# >`fe_0`: List of columns whose xgboost importance is zero<br>
# >`fe`: One-column dataframe of feature importance(top-down). Col name is 'imp'<br>

# %%
# 10.0 Get feature importance:
#      fe: Sorted Pandas DataFrame with column name and top-down feature impt 

fe_1, fe_0, fe = utils.xgImptFeatures(model_trans,  train_trans.iloc[:,len(cat_cols):].columns)
print("\n=== DataFrame  of impt features top-down =======\n")
fe.iloc[:5]
print("\n\n== Column-list whose feat impt >0 =======\n")
fe_1[:5]  # Arranged in descending order of impt
print("\n\n===Column-list whose feat impt is 0 =======\n")
fe_0[:5]
# Out:
# Order of feature importance is by 'gain'
#
# === DataFrame  of impt features top-down =======
#                                  imp
# deg_gravity_ck_ph           0.054338
# eig_gravity_ck_ph           0.037768
# eig_ph_ck_ph_p_urea         0.022525
# deg_gravity_ck_urea_p_calc  0.019962
# clu_gravity_ck_osmo_p_cond  0.016295
# == Column-list whose feat impt >0 =======
# ['deg_gravity_ck_ph',
#  'eig_gravity_ck_ph',
#  'eig_ph_ck_ph_p_urea',
#  'deg_gravity_ck_urea_p_calc',
#  'clu_gravity_ck_osmo_p_cond']
# ===Column-list whose feat impt is 0 =======
# ['eig_ph_ck_cond_p_urea',
#  'clu_ph_ck_urea_p_calc',
#  'bet_ph_ck_urea_p_calc',
#  'clu_gravity_ck_ph_p_osmo',
#  'deg_ph_ck_osmo_p_cond']

# %%
# 10.1 Cumulative sum of feature importance.
#      Last 100 columns have zero or (near zero)
#      importance:

plt.plot(range(len(fe)), fe['imp'].cumsum().values);
plt.grid();

# %%
# 10.2 A histogram plot of feature importance score
#      Most columns have feature impt below 0.01

sns.histplot(fe['imp'][fe_1]);

# %% [markdown]
# ## Correlation with orig columns
# Correlation of extracted features with original features

# %%
# 11.0 Take top 5 imp features:

tt = train_trans[fe_1[:10]].copy()
tt.shape  # (373, 5)
# Out:
# (373, 10)

# %%
# 11.1 Reindex orig_train and merge with 'tt':

ot= orig_train.reset_index(drop = True).copy()
result = ot.merge(tt, left_index = True, right_index=True )

# %% [markdown]
# Correlation heatmap shows good amount of correlation between the two sets of features

# %%
# 11.2 Correlation heatmap:

plt.figure(figsize = (12,12))
sns.heatmap(np.round(result.corr(),2), annot = True);

# %% [markdown]
# ## Distribution of columns
# Distribution of columns related to different centrality measures

# %% [markdown]
# ### Proportion of columns by centrality measure:

# %%
# 12.0 Our list of columns

colList = (train_trans.iloc[:,len(cat_cols):]).columns

# Count of columns by centrality measure and its plot:
f = utils.featureImptByCentFeatCounts(colList, normalize = True)
utils.plotSeries(f, "Proportions of columns as per centrality measure")

# %% [markdown]
# ### Proportions of columns by centrality whose impt is > 0

# %%
# 12.1 Extract column importance:

fe_1, fe_0,_ = utils.xgImptFeatures(model_trans, colList)
f"Columns whose impt is >0: {len(fe_1)}"
print("\n")
f"Columns whose impt is 0: {len(fe_0)}"
# Out:
# Order of feature importance is by 'gain'
# 'Columns whose impt is >0: 147'
# 'Columns whose impt is 0: 123'

# %%
# 12.2 Count of columns whose xgboost impt > 0 by centrality measure and its plot:
f = utils.featureImptByCentFeatCounts(fe_1, normalize = True)
utils.plotSeries(f, "Proportions of columns as per cent measure when impt > 0")

# %% [markdown]
# ### Proportions of columns by summed-up importance score of each centrality measure

# %%
# 13.0 Extract xgboost feature importance:
fe_1, _, fe = utils.xgImptFeatures(model_trans, colList)
# Out:
# Order of feature importance is by 'gain'

# %%
# 13.1 Column-wise importance score (whose impt > 0)
#      score is a Pandas Series
score = fe['imp'][fe_1]

# 13.2 Score of top-five columns:
score[:5]
# Out:
# eig_concavity_mean_ck_texture_mean                 0.074974
# deg_area_se_ck_texture_mean                        0.074818
# deg_concavity_mean_ck_concavity_worst              0.050471
# clu_area_mean_ck_area_se                           0.037946
# eig_concavity_worst_ck_area_mean_p_texture_mean    0.027861
# Name: imp, dtype: float32

# %%
# 13.3 Extract and plot total xgboost impt scores by centrality measure:

g = utils.featureImptByScore(score, fe_1, True)
utils.plotSeries(g, "Total xgboost feature impt score by centrality meansure")

# %% [markdown]
# ## Mutual information

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mi_scores = utils.calMIScores(train_trans[colList], ytr)
mi_scores[::3]  # show a few features with their MI scores
# Out:
# eig_area_mean_ck_concavity_worst_p_concavity_mean       0.411510
# eig_area_mean_ck_area_mean_p_area_se                    0.398181
# eig_area_mean_ck_area_mean_p_texture_mean               0.396951
# eig_area_mean_ck_area_se_p_concavity_worst              0.388818
# eig_area_mean_ck_area_mean_p_concavity_worst            0.386731
#                                                           ...
# deg_texture_mean_ck_concavity_worst_p_concavity_mean    0.048080
# eig_area_se_ck_concavity_worst                          0.043185
# deg_texture_mean_ck_area_mean_p_concavity_worst         0.032534
# bet_texture_mean_ck_area_se                             0.011870
# pr_texture_mean_ck_area_se                              0.000000
# Name: MI Scores, Length: 90, dtype: float64

# %%
fe.cumsum()
len(fe)
