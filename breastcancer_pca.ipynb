# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/CatEncodersFamily/blob/main/breastcancer_pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install catencfamily
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catencfamily
#   Downloading catencfamily-0.0.62-py3-none-any.whl (30 kB)
# Collecting cdlib (from catencfamily)
#   Downloading cdlib-0.2.6-py3-none-any.whl (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.6/228.6 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catencfamily) (3.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from catencfamily) (3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.5.3)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.0.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from catencfamily) (1.2.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.18.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (4.65.0)
# Collecting demon (from cdlib->catencfamily)
#   Downloading demon-2.0.6-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: python-louvain>=0.16 in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.16)
# Collecting nf1 (from cdlib->catencfamily)
#   Downloading nf1-0.0.4-py3-none-any.whl (18 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (1.10.1)
# Collecting pulp (from cdlib->catencfamily)
#   Downloading PuLP-2.7.0-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 83.0 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.12.2)
# Collecting eva-lcd (from cdlib->catencfamily)
#   Downloading eva_lcd-0.1.1-py3-none-any.whl (9.2 kB)
# Collecting bimlpa (from cdlib->catencfamily)
#   Downloading bimlpa-0.1.2-py3-none-any.whl (7.0 kB)
# Collecting markov-clustering (from cdlib->catencfamily)
#   Downloading markov_clustering-0.0.6.dev0-py3-none-any.whl (6.3 kB)
# Collecting chinese-whispers (from cdlib->catencfamily)
#   Downloading chinese_whispers-0.8.1-py3-none-any.whl (7.8 kB)
# Collecting python-igraph (from cdlib->catencfamily)
#   Downloading python-igraph-0.10.4.tar.gz (9.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting angel-cd (from cdlib->catencfamily)
#   Downloading angel_cd-1.0.3-py3-none-any.whl (10 kB)
# Requirement already satisfied: pooch in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (1.6.0)
# Collecting dynetx (from cdlib->catencfamily)
#   Downloading dynetx-0.3.1-py3-none-any.whl (39 kB)
# Collecting thresholdclustering (from cdlib->catencfamily)
#   Downloading thresholdclustering-1.1-py3-none-any.whl (5.3 kB)
# Collecting pyclustering (from cdlib->catencfamily)
#   Downloading pyclustering-0.10.1.2.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 67.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from cdlib->catencfamily) (0.29.34)
# Collecting python-Levenshtein (from cdlib->catencfamily)
#   Downloading python_Levenshtein-0.21.0-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catencfamily) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->catencfamily) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->catencfamily) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->catencfamily) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->catencfamily) (1.16.0)
# Collecting networkx (from catencfamily)
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from dynetx->cdlib->catencfamily) (4.4.2)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch->cdlib->catencfamily) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch->cdlib->catencfamily) (2.27.1)
# Collecting igraph==0.10.4 (from python-igraph->cdlib->catencfamily)
#   Downloading igraph-0.10.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 119.8 MB/s eta 0:00:00
# Collecting texttable>=1.6.2 (from igraph==0.10.4->python-igraph->cdlib->catencfamily)
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Collecting Levenshtein==0.21.0 (from python-Levenshtein->cdlib->catencfamily)
#   Downloading Levenshtein-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 22.5 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from Levenshtein==0.21.0->python-Levenshtein->cdlib->catencfamily)
#   Downloading rapidfuzz-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 115.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch->cdlib->catencfamily) (3.4)
# Building wheels for collected packages: pyclustering, python-igraph
#   Building wheel for pyclustering (setup.py) ... done
#   Created wheel for pyclustering: filename=pyclustering-0.10.1.2-py3-none-any.whl size=2395106 sha256=3ca8918d5c2b0176a664a42cc05a0911ad1f77300431c3d4f2dffd0c6a79cc31
#   Stored in directory: /root/.cache/pip/wheels/b5/42/97/11eee99f5c1e4fdfc170f0a54f9c9eb195df66edb4cf69f449
#   Building wheel for python-igraph (setup.py) ... done
#   Created wheel for python-igraph: filename=python_igraph-0.10.4-py3-none-any.whl size=9073 sha256=cbe773eb9daf834685e604072c05203befcbbc2e1cff49f0cc4b3a7c2a2d97c1
#   Stored in directory: /root/.cache/pip/wheels/49/27/15/dcf90953e3e3322e6f3e447514b20cf39b53c6518cb4a7bace
# Successfully built pyclustering python-igraph
# Installing collected packages: texttable, pulp, rapidfuzz, networkx, igraph, thresholdclustering, python-igraph, Levenshtein, eva-lcd, dynetx, demon, chinese-whispers, python-Levenshtein, pyclustering, nf1, markov-clustering, bimlpa, angel-cd, cdlib, catencfamily
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# Successfully installed Levenshtein-0.21.0 angel-cd-1.0.3 bimlpa-0.1.2 catencfamily-0.0.62 cdlib-0.2.6 chinese-whispers-0.8.1 demon-2.0.6 dynetx-0.3.1 eva-lcd-0.1.1 igraph-0.10.4 markov-clustering-0.0.6.dev0 networkx-2.8.8 nf1-0.0.4 pulp-2.7.0 pyclustering-0.10.1.2 python-Levenshtein-0.21.0 python-igraph-0.10.4 rapidfuzz-3.1.0 texttable-1.6.7 thresholdclustering-1.1

# %%
# 1.0 Call libraries
import pandas as pd
import numpy as np


# 1.01
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


# 1.02
import matplotlib.pyplot as plt
import seaborn as sns


# 1.03
import xgboost as xgb
from xgboost import plot_importance


# 1.04
from catencfamily.encoders import CatEncodersFamily
from catencfamily import utils


# 1.05 Misc
import os,gc , time
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool', 'leidenalg', 'infomap', 'wurlitzer', 'karateclub'}
# Note: to be able to use all overlapping methods, you need to install some additional packages:  {'karateclub', 'ASLPAw'}
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'wurlitzer', 'infomap', 'leidenalg'}

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Read Data
data = pd.read_csv("https://raw.githubusercontent.com/harnalashok/CatEncodersFamily/main/datasets/breastcancer.csv")

# %%
data.head(3)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38           122.8     1001.0
# 1    842517         M        20.57         17.77           132.9     1326.0
# 2  84300903         M        19.69         21.25           130.0     1203.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
# 2  ...          25.53            152.5      1709.0            0.1444
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
#
# [3 rows x 33 columns]

# %%
y = data.pop("diagnosis")
_ = data.pop("id")
_= data.pop("Unnamed: 32")

# %%
# Map target to 0 and 1
y = y.map({"M" : 1, "B": 0 })
y.value_counts(normalize = True)
# Out:
# 0    0.627417
# 1    0.372583
# Name: diagnosis, dtype: float64

# %%
# Check nulls
data.isnull().sum().sum()

# Rename columns with spaces:
data = data.rename(columns = { "concave points_mean" : "concave_points_mean",
                               "concave points_se" : "concave_points_se",
                               "concave points_worst" : "concave_points_worst"
                             }
                   )
# Out:
# 0

# %%
# Discretise all features of data. And also split dataset.
# into train/test
orig_train, orig_test, train_binned, test_binned  = utils.generateSklearnData(data,
                                                                              y,
                                                                              bins = 30,
                                                                              test_size = 0.1,
                                                                              genColName = False  # Keep orig col names
                                                                              )

# %%
# Check  original data:

orig_train.head(3)
orig_test.head(3)
orig_train.shape
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 451        19.21         18.57          125.50     1152.0           0.1053
# 476        14.71         21.59           95.55      656.9           0.1137
# 268        13.05         19.31           82.61      527.2           0.0806
#
#      compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 451           0.12670        0.132300             0.089940         0.1917
# 476           0.13650        0.129300             0.081230         0.2027
# 268           0.03789        0.000692             0.004167         0.1819
#
#      fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 451                 0.05961  ...          28.14           170.10      2145.0
# 476                 0.06758  ...          30.70           115.70       985.5
# 268                 0.05501  ...          22.25            90.24       624.1
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 451            0.1624            0.35110         0.387900
# 476            0.1368            0.42900         0.358700
# 268            0.1021            0.06191         0.001845
#
#      concave_points_worst  symmetry_worst  fractal_dimension_worst  target
# 451               0.20910          0.3537                  0.08294       1
# 476               0.18340          0.3698                  0.10940       1
# 268               0.01111          0.2439                  0.06289       0
#
# [3 rows x 31 columns]
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 278        17.99         10.38           122.8     1001.0          0.11840
# 4          20.57         17.77           132.9     1326.0          0.08474
# 511        19.69         21.25           130.0     1203.0          0.10960
#
#      compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 278           0.27760          0.3001              0.14710         0.2419
# 4             0.07864          0.0869              0.07017         0.1812
# 511           0.15990          0.1974              0.12790         0.2069
#
#      fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 278                 0.07871  ...          17.33            184.6      2019.0
# 4                   0.05667  ...          23.41            158.8      1956.0
# 511                 0.05999  ...          25.53            152.5      1709.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 278            0.1622             0.6656           0.7119
# 4              0.1238             0.1866           0.2416
# 511            0.1444             0.4245           0.4504
#
#      concave_points_worst  symmetry_worst  fractal_dimension_worst  target
# 278                0.2654          0.4601                  0.11890       1
# 4                  0.1860          0.2750                  0.08902       1
# 511                0.2430          0.3613                  0.08758       1
#
# [3 rows x 31 columns]
# (513, 31)

# %%
# Check discretised features
# train/test in binned data and original 
# split data have the same row-indicies:

train_binned.head(3)
test_binned.head(3)
train_binned.shape
# Out:
#     radius_mean texture_mean perimeter_mean area_mean smoothness_mean  \
# 451         418           89           1217      1613            2015
# 476         411          813           1211       167            2017
# 268          49          810            129       165             208
#
#     compactness_mean concavity_mean concave_points_mean symmetry_mean  \
# 451             2410           2810                3214          3613
# 476             2411           2810                3213          3615
# 268              242            281                 321          3612
#
#     fractal_dimension_mean  ... texture_worst perimeter_worst area_worst  \
# 451                    407  ...          8813            9218       9615
# 476                   4012  ...          8815            9210        966
# 268                    404  ...           889             926        964
#
#     smoothness_worst compactness_worst concavity_worst concave_points_worst  \
# 451            10019             10410           10810                11222
# 476            10014             10412            1089                11219
# 268             1007              1042            1081                 1122
#
#     symmetry_worst fractal_dimension_worst target
# 451          11612                    1206      1
# 476          11613                   12011      1
# 268           1166                    1202      0
#
# [3 rows x 31 columns]
#     radius_mean texture_mean perimeter_mean area_mean smoothness_mean  \
# 278         416           81           1217      1611            2018
# 4           420           89           1219      1616             209
# 511         419          812           1218      1614            2016
#
#     compactness_mean concavity_mean concave_points_mean symmetry_mean  \
# 278             2424           2822                3222          3621
# 4                246            287                3211          3612
# 511             2413           2814                3220          3616
#
#     fractal_dimension_mean  ... texture_worst perimeter_worst area_worst  \
# 278                   4019  ...           885            9221       9614
# 4                      405  ...          8810            9217       9614
# 511                    407  ...          8811            9216       9612
#
#     smoothness_worst compactness_worst concavity_worst concave_points_worst  \
# 278            10019             10419           10818                11228
# 4              10011              1045            1086                11220
# 511            10015             10412           10811                11226
#
#     symmetry_worst fractal_dimension_worst target
# 278          11618                   12013      1
# 4             1168                    1207      1
# 511          11613                    1207      1
#
# [3 rows x 31 columns]
# (513, 31)

# %%
# Pop out targets
ytr = train_binned.pop('target')
yte = test_binned.pop("target")

# %%
## Developing models
# Which are our cat columns
# We will consider few columns
# Ref: https://www.kaggle.com/code/kanncaa1/feature-selection-and-data-visualization

best_features= ["area_mean", "area_se", "texture_mean", "concavity_worst", "concavity_mean"]
cat_cols = list(train_binned[best_features].columns)
cat_cols
len(cat_cols)  # 5


# Keep interacting columns, same
# as cat columns:
interactingCatCols = cat_cols
# Out:
# ['area_mean', 'area_se', 'texture_mean', 'concavity_worst', 'concavity_mean']
# 5

# %%
# Instantiate CustomTransformer class:
ct = CatEncodersFamily(
                       cMeasures=[1,1,1,1,None,1,1],
                       )

# Fit it:
ct.fit(train_binned, cat_cols, interactingCatCols)

# %%
# Transform test_binned data with only cat_cols
test_trans = ct.transform(test_binned[cat_cols])
test_trans.shape
# Out:
# ====Reading all model-dicts from RAM
#
#
# ====All saved model-dicts read! Model files are intact!
# ====Total model-dict are:  350
# ====Sending model loading progress to file: /content/allmodels/progress/load_stored_models.txt
# When loading is in progress, open this file with notepad++ AND NOT with notepad
#
#
# Current mem usage is: 0.128248 MB
# Mem usage after dtype transformation is: 0.067768 MB
# (56, 275)

# %%
train_trans= ct.transform(train_binned[cat_cols])
train_trans.shape
# Out:
# ====Reading all model-dicts from RAM
#
#
# ====All saved model-dicts read! Model files are intact!
# ====Total model-dict are:  350
# ====Sending model loading progress to file: /content/allmodels/progress/load_stored_models.txt
# When loading is in progress, open this file with notepad++ AND NOT with notepad
#
#
# Current mem usage is: 1.121309 MB
# Mem usage after dtype transformation is: 0.567269 MB

# %%
train_trans.head()
test_trans.head()
# Out:
#   area_mean area_se texture_mean concavity_worst concavity_mean  \
# 0      1613     566           89           10810           2810
# 1       167     562          813            1089           2810
# 2       165     562          810            1081            281
# 3       162     561           83            1083            282
# 4       163     562           86            1081            281
#
#    deg_area_mean_ck_area_se  eig_area_mean_ck_area_se  \
# 0                  0.791667                  0.261167
# 1                  0.666667                  0.239339
# 2                  0.625000                  0.228916
# 3                  0.625000                  0.228916
# 4                  0.541667                  0.198357
#
#    pr_area_mean_ck_area_se  clu_area_mean_ck_area_se  \
# 0                 0.055585                  0.719298
# 1                 0.046617                  0.875000
# 2                 0.043844                  0.923810
# 3                 0.043844                  0.923810
# 4                 0.038763                  0.948718
#
#    bet_area_mean_ck_area_se  ...  eig_concavity_mean_ck_area_mean_p_area_se  \
# 0                  0.036874  ...                                   0.216064
# 1                  0.010891  ...                                   0.216064
# 2                  0.003943  ...                                   0.227932
# 3                  0.003943  ...                                   0.236322
# 4                  0.002104  ...                                   0.227932
#
#    pr_concavity_mean_ck_area_mean_p_area_se  \
# 0                                  0.040763
# 1                                  0.040763
# 2                                  0.050540
# 3                                  0.046357
# 4                                  0.050540
#
#    clu_concavity_mean_ck_area_mean_p_area_se  \
# 0                                   0.847619
# 1                                   0.847619
# 2                                   0.742647
# 3                                   0.808824
# 4                                   0.742647
#
#    bet_concavity_mean_ck_area_mean_p_area_se  \
# 0                                   0.005893
# 1                                   0.005893
# 2                                   0.076682
# 3                                   0.013674
# 4                                   0.076682
#
#    eig_concavity_mean_ck_texture_mean_p_concavity_mean  \
# 0                                           0.068685
# 1                                           0.068685
# 2                                          -0.116131
# 3                                           0.018458
# 4                                          -0.116131
#
#    deg_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                        0.500000
# 1                                        0.500000
# 2                                        0.500000
# 3                                        0.535714
# 4                                        0.500000
#
#    eig_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                        0.264371
# 1                                        0.264371
# 2                                        0.260705
# 3                                        0.279300
# 4                                        0.260705
#
#    pr_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                       0.051642
# 1                                       0.051642
# 2                                       0.052050
# 3                                       0.054516
# 4                                       0.052050
#
#    clu_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                        0.725275
# 1                                        0.725275
# 2                                        0.692308
# 3                                        0.704762
# 4                                        0.692308
#
#    bet_concavity_mean_ck_area_mean_p_texture_mean
# 0                                        0.026314
# 1                                        0.026314
# 2                                        0.029579
# 3                                        0.019581
# 4                                        0.029579
#
# [5 rows x 275 columns]
#   area_mean area_se texture_mean concavity_worst concavity_mean  \
# 0      1611     569           81           10818           2822
# 1      1616     564           89            1086            287
# 2      1614     565          812           10811           2814
# 3       164     562          811           10817           2817
# 4      1615     565           85           10810           2814
#
#    deg_area_mean_ck_area_se  eig_area_mean_ck_area_se  \
# 0                  0.833333                  0.265286
# 1                  0.833333                  0.265286
# 2                  0.791667                  0.253219
# 3                  0.625000                  0.228916
# 4                  0.750000                  0.249100
#
#    pr_area_mean_ck_area_se  clu_area_mean_ck_area_se  \
# 0                 0.059017                  0.663158
# 1                 0.059017                  0.663158
# 2                 0.056464                  0.672515
# 3                 0.043844                  0.923810
# 4                 0.053033                  0.732026
#
#    bet_area_mean_ck_area_se  ...  eig_concavity_mean_ck_area_mean_p_area_se  \
# 0                  0.054084  ...                                   0.155719
# 1                  0.054084  ...                                   0.261773
# 2                  0.046386  ...                                   0.224821
# 3                  0.003943  ...                                   0.124990
# 4                  0.030383  ...                                   0.224821
#
#    pr_concavity_mean_ck_area_mean_p_area_se  \
# 0                                  0.028551
# 1                                  0.057620
# 2                                  0.043535
# 3                                  0.031381
# 4                                  0.043535
#
#    clu_concavity_mean_ck_area_mean_p_area_se  \
# 0                                   1.000000
# 1                                   0.628571
# 2                                   0.816667
# 3                                   0.777778
# 4                                   0.816667
#
#    bet_concavity_mean_ck_area_mean_p_area_se  \
# 0                                   0.000000
# 1                                   0.071751
# 2                                   0.010002
# 3                                   0.066138
# 4                                   0.010002
#
#    eig_concavity_mean_ck_texture_mean_p_concavity_mean  \
# 0                                           0.138504
# 1                                           0.176602
# 2                                          -0.299602
# 3                                           0.108488
# 4                                          -0.299602
#
#    deg_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                        0.214286
# 1                                        0.607143
# 2                                        0.392857
# 3                                        0.214286
# 4                                        0.392857
#
#    eig_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                        0.128113
# 1                                        0.277972
# 2                                        0.193359
# 3                                        0.108101
# 4                                        0.193359
#
#    pr_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                       0.024595
# 1                                       0.064099
# 2                                       0.045656
# 3                                       0.029955
# 4                                       0.045656
#
#    clu_concavity_mean_ck_area_mean_p_texture_mean  \
# 0                                        1.000000
# 1                                        0.529412
# 2                                        0.600000
# 3                                        0.666667
# 4                                        0.600000
#
#    bet_concavity_mean_ck_area_mean_p_texture_mean
# 0                                        0.000000
# 1                                        0.079057
# 2                                        0.069138
# 3                                        0.063492
# 4                                        0.069138
#
# [5 rows x 275 columns]

# %%
_=orig_train.pop('target')

# %%
pca = PCA(n_components = 2,  whiten= True, random_state= None)
ss= StandardScaler()
dx = pca.fit_transform(ss.fit_transform(orig_train[cat_cols]))
dx.shape
# Out:
# (513, 2)

# %%
da = train_trans.iloc[:,5:]
da.isnull().sum().sum()  # If ot null perform imputation with SimpleImputer(strategy = 'median')
# Out:
# 0

# %%
pca = PCA(n_components= 2, whiten= True, random_state = None)
ss = StandardScaler()
da = pca.fit_transform(ss.fit_transform(da))
da.shape
# Out:
# (513, 2)

# %%
colnames = ["pc" + str(i) for i in range(dx.shape[1])]
dx = pd.DataFrame(dx, columns = colnames)
da = pd.DataFrame(da, columns = colnames)

# %%
dx.head()
# Out:
#         pc0       pc1
# 0  1.059960 -0.783274
# 1  0.390520  0.433347
# 2 -0.759325  0.382682
# 3 -1.172629 -1.296425
# 4 -1.010158 -0.638052

# %%
sns.scatterplot(data = da, x= 'pc0', y = 'pc1', hue = ytr.values)
# Out:
# <Axes: xlabel='pc0', ylabel='pc1'>

# %%
sns.scatterplot(data = dx, x= 'pc0', y = 'pc1', hue = ytr.values)
# Out:
# <Axes: xlabel='pc0', ylabel='pc1'>
